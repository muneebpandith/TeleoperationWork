# %%
input_cardinality=20
output_cardinality=6

# %%
import torch
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import sklearn.model_selection as sk
import torch.autograd as autograd
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

# %%
#import pytorch_lightning as pl
import time
import copy
from tqdm import tqdm

# %%
torch.manual_seed(0)
def seed_worker(worker_id):
    worker_seed = torch.initial_seed() % 2**32
    np.random.seed(worker_seed)
    random.seed(worker_seed)

g = torch.Generator()
g.manual_seed(0)

# %%
#from pytorch_lightning.callbacks import ModelCheckpoint, EarlyStopping
#from pytorch_lightning.loggers import TensorBoardLogger

# %%
device = torch.device("cpu" if torch.cuda.is_available() else "cpu")

# %%
#pl.seed_everything(43)

# %%
class DATA:
    def __init__(self, data_path):
        self.data_path = data_path
        self.filenames = os.listdir(DATA_PATH)
        self.filenames = [filename for filename in self.filenames if filename.endswith(".csv")]
        self.len_filenames = len(self.filenames)
        
    def get_data(self):
        self.data = []
        for i in range(len(self.filenames)):
            self.data.append(self.read_data(i))
        return self.data
    
    def read_data(self,i):
        return pd.read_csv(self.data_path+"/"+self.filenames[i])
    

    def process_data(self, scaler, input_cardinality=20, output_cardinality=10, cols=['ThetaXHG']):
        self.datasamples = self.get_data()
        X = []
        y = []
        X_scaled = []
        y_scaled = []
        for i, datasample in enumerate(self.datasamples):            
            #for j in range(datasample[cols].shape[0]-output_cardinality):
            #    print('Input' +str(j)+ ' to '+str(j+input_cardinality) + 'Output: '+str(j+input_cardinality)+ ' to '+str(j+input_cardinality+output_cardinality))
            #Append to X (TO MAKE A LIST OF LISTS), [[0.019,1.02,...., upto input_cardinality]]
            #Append to Y (TO MAKE A LIST OF LISTS), [[0.019,1.02,...., upto output_cardinality]]
            #start of Y will be ahead of end of X by 1
            
            for j in range(datasample.shape[0]-output_cardinality-input_cardinality+1):
                X.append(datasample[cols].iloc[j:j+input_cardinality].to_numpy())
                y.append(datasample[cols].iloc[j+input_cardinality: j+input_cardinality+output_cardinality].to_numpy())
                X_scaled.append(scaler.transform(datasample[cols].iloc[j:j+input_cardinality].to_numpy()))
                y_scaled.append(scaler.transform(datasample[cols].iloc[j+input_cardinality: j+input_cardinality+output_cardinality].to_numpy()))
        
        #return self.datasamples, X, y
        #print(np.array(X).shape,np.array(y).shape,np.array(X_scaled).shape, np.array(y_scaled).shape)
        return self.datasamples, np.array(X), np.array(y), np.array(X_scaled), np.array(y_scaled)
    
    
    def train_test_split(self, X, y, split={'train':0.8,'val':0.2, 'test':0.5}):
        #print(X)
        self.X_train, self.X_val_test, self.y_train, self.y_val_test = sk.train_test_split(X, y, test_size=split['val'] , random_state=43)
        self.X_test, self.X_val, self.y_test, self.y_val = sk.train_test_split(self.X_val_test, self.y_val_test, test_size=split['test'] , random_state=43)
        
        return (self.X_train, self.y_train), (self.X_val, self.X_test), (self.X_test, self.y_test)
    
    
    
    def getscaler(self,cols):
        self.datasamples = self.get_data()       
        for i, sample in enumerate(self.datasamples):
            if i ==0:
                features = pd.DataFrame(sample[cols])
            else:
                features = pd.DataFrame.append(features, sample[cols]) #sample[cols]
   
        #scaling
        scaler = MinMaxScaler(feature_range=(-1,1))
        scaler = scaler.fit(features)
        features_scaled = pd.DataFrame(scaler.transform(features), index = features.index, columns = cols)
        return scaler
    
        """        
        #convert back to datasamples
        #save to X
        #save to X_scaled
        
        
        #Split treain test and validation
        
        for i in range(features.shape[0]):
            self.datasamples = []
            
        
        
        
        return features, features_scaled
        """

# %%
class THETADATASET(Dataset):
    #convert to pytorch dataset
    def __init__(self, X, y):
        self.X = X
        self.y = y
    def __len__(self):
        return len(self.X)
    def __getitem__(self, idx):
        sequence, output = self.X[idx], self.y[idx]
        return (torch.from_numpy(sequence.reshape(-1)), torch.from_numpy(output.reshape(-1)))
        #return dict(sequence=torch.tensor(sequence.reshape(-1),dtype=torch.float64), label=torch.tensor(output.reshape(-1),dtype=torch.float64))

# %%
class THETADATASETLOADER():
    def __init__(self, data, batchsize, bs_val):
        super().__init__()
        self.data = data
        self.batchsize = batchsize
        self.train_dataset = THETADATASET(self.data.X_train, self.data.y_train)
        self.val_dataset = THETADATASET(self.data.X_val, self.data.y_val)
        self.test_dataset = THETADATASET(self.data.X_test, self.data.y_test)
        self.train_dataloader = DataLoader(self.train_dataset, batch_size = self.batchsize, shuffle= False, num_workers=0, worker_init_fn=seed_worker,generator=g)
        self.val_dataloader = DataLoader(self.val_dataset, batch_size = bs_val, shuffle= False, num_workers=0,  worker_init_fn=seed_worker,generator=g)
        self.test_dataloader = DataLoader(self.test_dataset, batch_size = 1, shuffle= False, num_workers=0,  worker_init_fn=seed_worker,generator=g)

# %%
#dataloaders={}
#dataloaders['train'], dataloaders['val'] = data_loaded.train_dataloader, data_loaded.val_dataloader

# %%
"""
for f, o in tqdm(dataloaders['train']):
    #print(f[0].shape)
    break
"""
# Out:
# "\nfor f, o in tqdm(dataloaders['train']):\n    #print(f[0].shape)\n    break\n"

# %%
#loss_fn(a,first['label'])

# %%
#X_test.shape

# %%
def train_model(DATA_LOADED, model, criterion, optimizer, num_epochs=25):
    #train_model(DATA_LOADED, model, criterion, optimizer, scheduler, num_epochs=25):
    start = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_loss = 0
    dataloaders ={}
    dataloaders['train'], dataloaders['val'] = DATA_LOADED.train_dataloader, DATA_LOADED.val_dataloader

    #TR_ACCURACY=[]
    TR_LOSS=[]
    #VAL_ACCURACY=[]
    VAL_LOSS=[]
    for epoch in range(num_epochs):
        model.reset_hidden_states()
        #model.reset_hidden_states()
        #print(model.hidden)
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            #running_corrects = 0

            # Iterate over data.
            for inputs, labels in tqdm(dataloaders[phase]):
                inputs = inputs.to(device)
                labels = labels.to(device)

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    loss = criterion(outputs, labels)
                    #_, preds = torch.max(outputs, 1)
                # backward + optimize only if in training phase
                if phase == 'train':
                    optimizer.zero_grad()
                    loss.backward()
                    optimizer.step()

                # statistics
                running_loss += loss.item()
                #running_corrects += torch.sum(preds == labels.data)

            #if phase == 'train':
            #    scheduler.step()

            #epoch_loss = running_loss / DATA_LOADED.dataset_sizes[phase]
            epoch_loss = running_loss / dataset_size[phase]
            
            #epoch_acc = running_corrects.double() / DATA.dataset_sizes[phase]

            print('{} Loss: {:.4f}'.format(phase, epoch_loss))
            

            if phase == 'train':
                #  print("Training")
                #  TR_ACCURACY.append(epoch_acc)
                TR_LOSS.append(epoch_loss)
            else:
                print("Valuation")
                #VAL_ACCURACY.append(epoch_acc)
                VAL_LOSS.append(epoch_loss)

            # deep copy the model
            if phase == 'val' and epoch_loss < best_loss:
                best_loss = epoch_loss
                best_model_wts = copy.deepcopy(model.state_dict())


    time_elapsed = time.time() - start
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    #print('Best val Acc: {:4f}'.format(best_acc))

    model.load_state_dict(best_model_wts)
    return TR_LOSS, VAL_LOSS, model

# %%
class CHALLEABLELSTMNET(nn.Module):
    def __init__(self, batch_size, input_len, output_len, lstm_units = 4, num_layers=1):
        super(LSTMNET, self).__init__()
        self.input_len = input_len
        self.output_len = output_len
        self.num_layers = num_layers
        self.batch_size = batch_size
        #input_size = no of features = 1
        #hidden_size = no of lstm units in the layer
        #num_layers = no of lstm layers
        self.lstm_units = lstm_units
        self.lstm1 = nn.LSTM(input_size= 1, hidden_size= lstm_units, num_layers=num_layers,batch_first=True, dropout=0.6)
        
        self.linear0 = nn.Linear(in_features= 20, out_features=10)
        
        self.linear1 = nn.Linear(in_features= lstm_units, out_features=10)
        self.linear2 = nn.Linear(in_features= 10, out_features=10)
        self.ll = nn.Linear(in_features= 10, out_features=output_len)
        self.hidden = (torch.zeros(1*self.num_layers, self.batch_size, self.lstm_units).to(device).double(), torch.zeros(1*self.num_layers, self.batch_size, self.lstm_units).to(device).double())
        #print(self.hidden[0].device)
        #print(self.hidden.shape)
        #self.hidden[0]= self.hidden[0].to(device)
        #self.hidden[1] = self.hidden[1].to(device)
        self.tanh = nn.Tanh()
        self.sigmoid = nn.Sigmoid()
    def reset_hidden_states(self):
        self.hidden = (torch.zeros(1*self.num_layers, self.batch_size, self.lstm_units).double(), torch.zeros(1*self.num_layers, self.batch_size, self.lstm_units).double())
    def forward(self,x):
        #print(x.shape)
        #print(x)
        #print(x.unsqueeze(-1).shape)
        #print(self.hidden.shape)
        #print(self.hidden)
        #lstm_out, (h,c) = self.lstm1(x.unsqueeze(-1), self.hidden)
        #self.hidden= (h.detach(),c.detach())
        #c.detach_()
        #h.detach_()
        #self.hidden = (h.detach(), c.detach())
        #print(ht.shape)
        #ht=ht.to(device)
        #ct=ct.to(device)
        
        #lstm_out = lstm_out[:,-1,:]
        #print(ht.shape)
        #either lstm_out goes to next or ht goes
        #lstm_out= ht[-1]
        #lin1_out = self.linear1(lstm_out)
        #Add RELU
        lin0_out = F.relu(self.linear0(x))
        ll_out = self.ll(lin0_out)
        #x = self.linear0(x)
        #print(x.shape)
        
        #x = self.linear2(x)
        #Add RELU
        return ll_out

# %%
class LSTMNET(nn.Module):
    def __init__(self, batch_size, input_len, output_len, lstm_units = 4, num_layers=1):
        super(LSTMNET, self).__init__()
        self.input_len = input_len
        self.output_len = output_len
        self.num_layers = num_layers
        self.batch_size = batch_size
        #input_size = no of features = 1
        #hidden_size = no of lstm units in the layer
        #num_layers = no of lstm layers
        self.lstm_units = lstm_units
        self.lstm1 = nn.LSTM(input_size= 1, hidden_size= lstm_units, num_layers=num_layers,batch_first=True, dropout=0.6)
        
        self.linear0 = nn.Linear(in_features= 20, out_features=10)
        
        self.linear1 = nn.Linear(in_features= lstm_units, out_features=10)
        self.linear2 = nn.Linear(in_features= 10, out_features=10)
        self.ll = nn.Linear(in_features= 10, out_features=output_len)
        self.hidden = (torch.zeros(1*self.num_layers, self.batch_size, self.lstm_units).double(), torch.zeros(1*self.num_layers, self.batch_size, self.lstm_units).double())
        #print(self.hidden[0].device)
        #print(self.hidden.shape)
        #self.hidden[0]= self.hidden[0].to(device)
        #self.hidden[1] = self.hidden[1].to(device)
        self.tanh = nn.Tanh()
        self.sigmoid = nn.Sigmoid()
    
    def reset_hidden_states(self,bs):
        self.hidden = (torch.zeros(1*self.num_layers, bs, self.lstm_units).double(), torch.zeros(1*self.num_layers, bs, self.lstm_units).double())
        
    def forward(self,x):
        #print(x.shape)
        #print(x)
        #print(x.unsqueeze(-1).shape)
        #print(self.hidden.shape)
        #print(self.hidden)
        lstm_out, (h,c) = self.lstm1(x.unsqueeze(-1), self.hidden)
        self.hidden= (h.detach(),c.detach())
        #c.detach_()
        #h.detach_()
        #self.hidden = (h.detach(), c.detach())
        #print(ht.shape)
        #ht=ht.to(device)
        #ct=ct.to(device)
        
        lstm_out = lstm_out[:,-1,:]
        #print(ht.shape)
        #either lstm_out goes to next or ht goes
        #lstm_out= h.detach()[-1]
        lin1_out = self.linear1(lstm_out)
        #Add RELU
        #lin0_out = F.relu(self.linear0(x))
        ll_out = self.ll(lin1_out)
        #x = self.linear0(x)
        #print(x.shape)
        
        #x = self.linear2(x)
        #Add RELU
        return ll_out

# %%
#X_train.shape

# %%
epochs=500
batch_size = 16
bs_val = 16

# %%
# !ls
# Out:
# Lookahead1.ipynb  Lookahead3.ipynb  Lookahead5.ipynb  readme.md
# Lookahead2.ipynb  Lookahead4.ipynb  Lookahead6.ipynb

# %%
DATA_PATH = "../DATASET/TRANSORMER_DATA"
data = DATA(DATA_PATH)
cols=['ThetaXHG']
scaler = data.getscaler(cols)

# %%
samples, X, y, X_scaled, y_scaled = data.process_data(scaler, input_cardinality=input_cardinality, output_cardinality=output_cardinality, cols=['ThetaXHG'])
(X_train, y_train), (X_val, y_val), (X_test, y_test) = data.train_test_split(X_scaled,y_scaled,  split={'train':0.8,'val':0.2, 'test':0.5})

# %%
y.shape
# Out:
# (1075, 6, 1)

# %%
net = LSTMNET(batch_size=batch_size,input_len=input_cardinality,output_len=output_cardinality)
net = net.to(device)
net = net.double()
criterion = nn.MSELoss()
optimizer = optim.Adam(net.parameters(),lr=1e-1)
# Out:
# /home/toor/anaconda3/envs/py37/lib/python3.7/site-packages/torch/nn/modules/rnn.py:65: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.6 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))

# %%
#first['sequence'].double()

# %%
data_loaded = THETADATASETLOADER(data, batchsize=batch_size, bs_val = bs_val)

# %%
dataset_size={}
dataset_size['train'] =X_train.shape[0]
dataset_size['val'] =X_val.shape[0]
dataset_size['test'] =X_test.shape[0]

# %%
TR_LOSS = []
VAL_LOSS = []

# %%
722/16
# Out:
# 45.125

# %%
#Do separately Val loss and train loss
"""for i in range(epochs):
    net.reset_hidden_states(bs=batch_size)
    it = iter(data_loaded.train_dataloader)
    it_val = iter(data_loaded.train_dataloader)
    print('Epoch'+str(i))
    c = 0
    tr_loss = 0.0
    val_loss = 0.0
    
    while c < int(X_train.shape[0]/batch_size): 
        with torch.set_grad_enabled(True):
            #print(c)
            c = c+1
            item = next(it)
            outputs = net(item[0])
            tr_loss = tr_loss + criterion(outputs, item[1])
    
    TR_LOSS.append(tr_loss)
    print(tr_loss)
    optimizer.zero_grad()
    tr_loss.backward()
    optimizer.step()
    
    net.reset_hidden_states(bs=bs_val)
    #print(net.hidden[0].shape)
    while c < int(X_val.shape[0]/bs_val):
        net.eval()
        with torch.set_grad_enabled(False):
            #print(c)
            c = c+1
            item = next(it_val)
            outputs = net(item[0])
            val_loss = val_loss + criterion(outputs, item[1])
    VAL_LOSS.append(val_loss)
"""
# Out:
# "for i in range(epochs):\n    net.reset_hidden_states(bs=batch_size)\n    it = iter(data_loaded.train_dataloader)\n    it_val = iter(data_loaded.train_dataloader)\n    print('Epoch'+str(i))\n    c = 0\n    tr_loss = 0.0\n    val_loss = 0.0\n    \n    while c < int(X_train.shape[0]/batch_size): \n        with torch.set_grad_enabled(True):\n            #print(c)\n            c = c+1\n            item = next(it)\n            outputs = net(item[0])\n            tr_loss = tr_loss + criterion(outputs, item[1])\n    \n    TR_LOSS.append(tr_loss)\n    print(tr_loss)\n    optimizer.zero_grad()\n    tr_loss.backward()\n    optimizer.step()\n    \n    net.reset_hidden_states(bs=bs_val)\n    #print(net.hidden[0].shape)\n    while c < int(X_val.shape[0]/bs_val):\n        net.eval()\n        with torch.set_grad_enabled(False):\n            #print(c)\n            c = c+1\n            item = next(it_val)\n            outputs = net(item[0])\n            val_loss = val_loss + criterion(outputs, item[1])\n    VAL_LOSS.append(val_loss)\n"

# %%
#Do separately Val loss and train loss
TR_LOSS = []
VAL_LOSS = []
for i in range(epochs):
    net.train()
    net.reset_hidden_states(bs=batch_size)
    #print(net.hidden[0].shape)
    it = iter(data_loaded.train_dataloader)
    it_val = iter(data_loaded.train_dataloader)
    c = 0
    tr_loss = 0.0
    val_loss = 0.0
    while c < int(X_train.shape[0]/batch_size): 
        with torch.set_grad_enabled(True):
            #print(c)
            c = c+1
            item = next(it)
            inputs = item[0].to(device)
            labels = item[1].to(device)
            
            outputs = net(inputs)
            tr_loss = tr_loss + criterion(outputs, labels)
    
    TR_LOSS.append(tr_loss)
    print(tr_loss)
    optimizer.zero_grad()
    tr_loss.backward()
    optimizer.step()
    c = 0
    
    #net.reset_hidden_states(bs=bs_val)
    #print(net.hidden[0].shape)
    #print(net.hidden[0].shape)
    while c < int(X_val.shape[0]/bs_val):
        net.eval()
        with torch.set_grad_enabled(False):
            #print(c)
            c = c+1
            item = next(it_val)
            inputs = item[0].to(device)
            labels = item[1].to(device)
            
            outputs = net(inputs)
            val_loss = val_loss + criterion(outputs, labels)
            #print(val_loss)
    VAL_LOSS.append(val_loss)
    print('Epoch'+str(i)+ ' >> Training Loss: '+str(tr_loss)+ ' Validation Loss: '+str(val_loss)+ ' <<')
# Out:
# tensor(16.8401, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch0 >> Training Loss: tensor(16.8401, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.8518, dtype=torch.float64) <<
# tensor(7.0487, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch1 >> Training Loss: tensor(7.0487, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.7910, dtype=torch.float64) <<
# tensor(6.4894, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch2 >> Training Loss: tensor(6.4894, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.8793, dtype=torch.float64) <<
# tensor(7.0153, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch3 >> Training Loss: tensor(7.0153, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.7534, dtype=torch.float64) <<
# tensor(6.0320, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch4 >> Training Loss: tensor(6.0320, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.7038, dtype=torch.float64) <<
# tensor(5.7258, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch5 >> Training Loss: tensor(5.7258, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.5797, dtype=torch.float64) <<
# tensor(4.6159, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch6 >> Training Loss: tensor(4.6159, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.5451, dtype=torch.float64) <<
# tensor(4.3478, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch7 >> Training Loss: tensor(4.3478, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.4005, dtype=torch.float64) <<
# tensor(3.2367, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch8 >> Training Loss: tensor(3.2367, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.3204, dtype=torch.float64) <<
# tensor(2.6657, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch9 >> Training Loss: tensor(2.6657, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.1475, dtype=torch.float64) <<
# tensor(1.2176, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch10 >> Training Loss: tensor(1.2176, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.1075, dtype=torch.float64) <<
# tensor(1.0419, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch11 >> Training Loss: tensor(1.0419, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.3604, dtype=torch.float64) <<
# tensor(3.1896, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch12 >> Training Loss: tensor(3.1896, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.3467, dtype=torch.float64) <<
# tensor(3.4704, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch13 >> Training Loss: tensor(3.4704, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.1217, dtype=torch.float64) <<
# tensor(1.2641, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch14 >> Training Loss: tensor(1.2641, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.1270, dtype=torch.float64) <<
# tensor(1.1203, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch15 >> Training Loss: tensor(1.1203, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.1391, dtype=torch.float64) <<
# tensor(1.2085, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch16 >> Training Loss: tensor(1.2085, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0652, dtype=torch.float64) <<
# tensor(0.5447, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch17 >> Training Loss: tensor(0.5447, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.1304, dtype=torch.float64) <<
# tensor(1.0750, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch18 >> Training Loss: tensor(1.0750, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.1567, dtype=torch.float64) <<
# tensor(1.2837, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch19 >> Training Loss: tensor(1.2837, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.1120, dtype=torch.float64) <<
# tensor(0.9062, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch20 >> Training Loss: tensor(0.9062, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.1149, dtype=torch.float64) <<
# tensor(0.9677, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch21 >> Training Loss: tensor(0.9677, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.1413, dtype=torch.float64) <<
# tensor(1.2226, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch22 >> Training Loss: tensor(1.2226, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.1026, dtype=torch.float64) <<
# tensor(0.8777, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch23 >> Training Loss: tensor(0.8777, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0750, dtype=torch.float64) <<
# tensor(0.6206, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch24 >> Training Loss: tensor(0.6206, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0944, dtype=torch.float64) <<
# tensor(0.7884, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch25 >> Training Loss: tensor(0.7884, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0724, dtype=torch.float64) <<
# tensor(0.6091, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch26 >> Training Loss: tensor(0.6091, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0480, dtype=torch.float64) <<
# tensor(0.4068, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch27 >> Training Loss: tensor(0.4068, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0787, dtype=torch.float64) <<
# tensor(0.6757, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch28 >> Training Loss: tensor(0.6757, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0649, dtype=torch.float64) <<
# tensor(0.5549, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch29 >> Training Loss: tensor(0.5549, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0568, dtype=torch.float64) <<
# tensor(0.4921, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch30 >> Training Loss: tensor(0.4921, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0709, dtype=torch.float64) <<
# tensor(0.6248, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch31 >> Training Loss: tensor(0.6248, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0444, dtype=torch.float64) <<
# tensor(0.3980, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch32 >> Training Loss: tensor(0.3980, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0391, dtype=torch.float64) <<
# tensor(0.3586, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch33 >> Training Loss: tensor(0.3586, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0425, dtype=torch.float64) <<
# tensor(0.3946, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch34 >> Training Loss: tensor(0.3946, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0259, dtype=torch.float64) <<
# tensor(0.2479, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch35 >> Training Loss: tensor(0.2479, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0314, dtype=torch.float64) <<
# tensor(0.2896, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch36 >> Training Loss: tensor(0.2896, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0390, dtype=torch.float64) <<
# tensor(0.3519, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch37 >> Training Loss: tensor(0.3519, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0311, dtype=torch.float64) <<
# tensor(0.2861, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch38 >> Training Loss: tensor(0.2861, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0342, dtype=torch.float64) <<
# tensor(0.3195, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch39 >> Training Loss: tensor(0.3195, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0385, dtype=torch.float64) <<
# tensor(0.3610, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch40 >> Training Loss: tensor(0.3610, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0303, dtype=torch.float64) <<
# tensor(0.2887, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch41 >> Training Loss: tensor(0.2887, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0302, dtype=torch.float64) <<
# tensor(0.2895, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch42 >> Training Loss: tensor(0.2895, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0307, dtype=torch.float64) <<
# tensor(0.3003, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch43 >> Training Loss: tensor(0.3003, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0226, dtype=torch.float64) <<
# tensor(0.2369, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch44 >> Training Loss: tensor(0.2369, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0240, dtype=torch.float64) <<
# tensor(0.2548, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch45 >> Training Loss: tensor(0.2548, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0246, dtype=torch.float64) <<
# tensor(0.2638, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch46 >> Training Loss: tensor(0.2638, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0201, dtype=torch.float64) <<
# tensor(0.2306, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch47 >> Training Loss: tensor(0.2306, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0231, dtype=torch.float64) <<
# tensor(0.2624, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch48 >> Training Loss: tensor(0.2624, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0208, dtype=torch.float64) <<
# tensor(0.2423, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch49 >> Training Loss: tensor(0.2423, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0189, dtype=torch.float64) <<
# tensor(0.2229, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch50 >> Training Loss: tensor(0.2229, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0208, dtype=torch.float64) <<
# tensor(0.2367, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch51 >> Training Loss: tensor(0.2367, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0176, dtype=torch.float64) <<
# tensor(0.2076, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch52 >> Training Loss: tensor(0.2076, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0185, dtype=torch.float64) <<
# tensor(0.2133, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch53 >> Training Loss: tensor(0.2133, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0198, dtype=torch.float64) <<
# tensor(0.2219, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch54 >> Training Loss: tensor(0.2219, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0187, dtype=torch.float64) <<
# tensor(0.2096, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch55 >> Training Loss: tensor(0.2096, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0206, dtype=torch.float64) <<
# tensor(0.2253, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch56 >> Training Loss: tensor(0.2253, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0203, dtype=torch.float64) <<
# tensor(0.2222, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch57 >> Training Loss: tensor(0.2222, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0192, dtype=torch.float64) <<
# tensor(0.2135, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch58 >> Training Loss: tensor(0.2135, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0199, dtype=torch.float64) <<
# tensor(0.2205, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch59 >> Training Loss: tensor(0.2205, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0182, dtype=torch.float64) <<
# tensor(0.2079, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch60 >> Training Loss: tensor(0.2079, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0179, dtype=torch.float64) <<
# tensor(0.2065, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch61 >> Training Loss: tensor(0.2065, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0180, dtype=torch.float64) <<
# tensor(0.2090, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch62 >> Training Loss: tensor(0.2090, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0169, dtype=torch.float64) <<
# tensor(0.2008, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch63 >> Training Loss: tensor(0.2008, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0176, dtype=torch.float64) <<
# tensor(0.2071, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch64 >> Training Loss: tensor(0.2071, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0172, dtype=torch.float64) <<
# tensor(0.2034, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch65 >> Training Loss: tensor(0.2034, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0171, dtype=torch.float64) <<
# tensor(0.2012, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch66 >> Training Loss: tensor(0.2012, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0175, dtype=torch.float64) <<
# tensor(0.2035, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch67 >> Training Loss: tensor(0.2035, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0169, dtype=torch.float64) <<
# tensor(0.1970, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch68 >> Training Loss: tensor(0.1970, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0174, dtype=torch.float64) <<
# tensor(0.1994, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch69 >> Training Loss: tensor(0.1994, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0174, dtype=torch.float64) <<
# tensor(0.1978, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch70 >> Training Loss: tensor(0.1978, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0174, dtype=torch.float64) <<
# tensor(0.1969, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch71 >> Training Loss: tensor(0.1969, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0178, dtype=torch.float64) <<
# tensor(0.2001, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch72 >> Training Loss: tensor(0.2001, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0176, dtype=torch.float64) <<
# tensor(0.1974, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch73 >> Training Loss: tensor(0.1974, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0178, dtype=torch.float64) <<
# tensor(0.1990, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch74 >> Training Loss: tensor(0.1990, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0176, dtype=torch.float64) <<
# tensor(0.1978, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch75 >> Training Loss: tensor(0.1978, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0173, dtype=torch.float64) <<
# tensor(0.1959, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch76 >> Training Loss: tensor(0.1959, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0174, dtype=torch.float64) <<
# tensor(0.1968, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch77 >> Training Loss: tensor(0.1968, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0170, dtype=torch.float64) <<
# tensor(0.1946, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch78 >> Training Loss: tensor(0.1946, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0171, dtype=torch.float64) <<
# tensor(0.1958, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch79 >> Training Loss: tensor(0.1958, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0170, dtype=torch.float64) <<
# tensor(0.1952, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch80 >> Training Loss: tensor(0.1952, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0169, dtype=torch.float64) <<
# tensor(0.1948, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch81 >> Training Loss: tensor(0.1948, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0169, dtype=torch.float64) <<
# tensor(0.1952, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch82 >> Training Loss: tensor(0.1952, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0168, dtype=torch.float64) <<
# tensor(0.1937, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch83 >> Training Loss: tensor(0.1937, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0169, dtype=torch.float64) <<
# tensor(0.1942, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch84 >> Training Loss: tensor(0.1942, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0168, dtype=torch.float64) <<
# tensor(0.1933, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch85 >> Training Loss: tensor(0.1933, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0168, dtype=torch.float64) <<
# tensor(0.1934, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch86 >> Training Loss: tensor(0.1934, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0168, dtype=torch.float64) <<
# tensor(0.1934, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch87 >> Training Loss: tensor(0.1934, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0167, dtype=torch.float64) <<
# tensor(0.1930, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch88 >> Training Loss: tensor(0.1930, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0168, dtype=torch.float64) <<
# tensor(0.1933, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch89 >> Training Loss: tensor(0.1933, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0166, dtype=torch.float64) <<
# tensor(0.1926, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch90 >> Training Loss: tensor(0.1926, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0166, dtype=torch.float64) <<
# tensor(0.1927, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch91 >> Training Loss: tensor(0.1927, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0165, dtype=torch.float64) <<
# tensor(0.1922, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch92 >> Training Loss: tensor(0.1922, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0164, dtype=torch.float64) <<
# tensor(0.1921, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch93 >> Training Loss: tensor(0.1921, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0164, dtype=torch.float64) <<
# tensor(0.1921, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch94 >> Training Loss: tensor(0.1921, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0163, dtype=torch.float64) <<
# tensor(0.1918, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch95 >> Training Loss: tensor(0.1918, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0163, dtype=torch.float64) <<
# tensor(0.1919, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch96 >> Training Loss: tensor(0.1919, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0163, dtype=torch.float64) <<
# tensor(0.1915, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch97 >> Training Loss: tensor(0.1915, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0163, dtype=torch.float64) <<
# tensor(0.1915, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch98 >> Training Loss: tensor(0.1915, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0163, dtype=torch.float64) <<
# tensor(0.1912, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch99 >> Training Loss: tensor(0.1912, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0163, dtype=torch.float64) <<
# tensor(0.1911, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch100 >> Training Loss: tensor(0.1911, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0163, dtype=torch.float64) <<
# tensor(0.1910, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch101 >> Training Loss: tensor(0.1910, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0163, dtype=torch.float64) <<
# tensor(0.1908, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch102 >> Training Loss: tensor(0.1908, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0163, dtype=torch.float64) <<
# tensor(0.1908, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch103 >> Training Loss: tensor(0.1908, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0163, dtype=torch.float64) <<
# tensor(0.1906, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch104 >> Training Loss: tensor(0.1906, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0162, dtype=torch.float64) <<
# tensor(0.1906, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch105 >> Training Loss: tensor(0.1906, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0162, dtype=torch.float64) <<
# tensor(0.1903, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch106 >> Training Loss: tensor(0.1903, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0162, dtype=torch.float64) <<
# tensor(0.1903, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch107 >> Training Loss: tensor(0.1903, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0161, dtype=torch.float64) <<
# tensor(0.1901, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch108 >> Training Loss: tensor(0.1901, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0161, dtype=torch.float64) <<
# tensor(0.1900, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch109 >> Training Loss: tensor(0.1900, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0161, dtype=torch.float64) <<
# tensor(0.1899, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch110 >> Training Loss: tensor(0.1899, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0161, dtype=torch.float64) <<
# tensor(0.1898, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch111 >> Training Loss: tensor(0.1898, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0161, dtype=torch.float64) <<
# tensor(0.1897, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch112 >> Training Loss: tensor(0.1897, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0161, dtype=torch.float64) <<
# tensor(0.1895, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch113 >> Training Loss: tensor(0.1895, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0161, dtype=torch.float64) <<
# tensor(0.1894, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch114 >> Training Loss: tensor(0.1894, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0161, dtype=torch.float64) <<
# tensor(0.1893, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch115 >> Training Loss: tensor(0.1893, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0161, dtype=torch.float64) <<
# tensor(0.1892, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch116 >> Training Loss: tensor(0.1892, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0161, dtype=torch.float64) <<
# tensor(0.1890, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch117 >> Training Loss: tensor(0.1890, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0160, dtype=torch.float64) <<
# tensor(0.1890, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch118 >> Training Loss: tensor(0.1890, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0160, dtype=torch.float64) <<
# tensor(0.1888, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch119 >> Training Loss: tensor(0.1888, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0160, dtype=torch.float64) <<
# tensor(0.1887, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch120 >> Training Loss: tensor(0.1887, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0160, dtype=torch.float64) <<
# tensor(0.1886, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch121 >> Training Loss: tensor(0.1886, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0160, dtype=torch.float64) <<
# tensor(0.1885, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch122 >> Training Loss: tensor(0.1885, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0159, dtype=torch.float64) <<
# tensor(0.1884, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch123 >> Training Loss: tensor(0.1884, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0159, dtype=torch.float64) <<
# tensor(0.1883, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch124 >> Training Loss: tensor(0.1883, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0159, dtype=torch.float64) <<
# tensor(0.1882, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch125 >> Training Loss: tensor(0.1882, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0159, dtype=torch.float64) <<
# tensor(0.1881, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch126 >> Training Loss: tensor(0.1881, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0159, dtype=torch.float64) <<
# tensor(0.1880, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch127 >> Training Loss: tensor(0.1880, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0159, dtype=torch.float64) <<
# tensor(0.1879, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch128 >> Training Loss: tensor(0.1879, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0159, dtype=torch.float64) <<
# tensor(0.1878, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch129 >> Training Loss: tensor(0.1878, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0158, dtype=torch.float64) <<
# tensor(0.1876, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch130 >> Training Loss: tensor(0.1876, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0158, dtype=torch.float64) <<
# tensor(0.1876, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch131 >> Training Loss: tensor(0.1876, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0158, dtype=torch.float64) <<
# tensor(0.1874, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch132 >> Training Loss: tensor(0.1874, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0158, dtype=torch.float64) <<
# tensor(0.1873, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch133 >> Training Loss: tensor(0.1873, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0158, dtype=torch.float64) <<
# tensor(0.1872, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch134 >> Training Loss: tensor(0.1872, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0158, dtype=torch.float64) <<
# tensor(0.1871, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch135 >> Training Loss: tensor(0.1871, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0157, dtype=torch.float64) <<
# tensor(0.1870, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch136 >> Training Loss: tensor(0.1870, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0157, dtype=torch.float64) <<
# tensor(0.1869, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch137 >> Training Loss: tensor(0.1869, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0157, dtype=torch.float64) <<
# tensor(0.1868, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch138 >> Training Loss: tensor(0.1868, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0157, dtype=torch.float64) <<
# tensor(0.1867, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch139 >> Training Loss: tensor(0.1867, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0157, dtype=torch.float64) <<
# tensor(0.1866, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch140 >> Training Loss: tensor(0.1866, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0157, dtype=torch.float64) <<
# tensor(0.1865, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch141 >> Training Loss: tensor(0.1865, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0156, dtype=torch.float64) <<
# tensor(0.1864, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch142 >> Training Loss: tensor(0.1864, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0156, dtype=torch.float64) <<
# tensor(0.1863, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch143 >> Training Loss: tensor(0.1863, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0156, dtype=torch.float64) <<
# tensor(0.1862, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch144 >> Training Loss: tensor(0.1862, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0156, dtype=torch.float64) <<
# tensor(0.1861, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch145 >> Training Loss: tensor(0.1861, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0156, dtype=torch.float64) <<
# tensor(0.1860, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch146 >> Training Loss: tensor(0.1860, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0156, dtype=torch.float64) <<
# tensor(0.1859, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch147 >> Training Loss: tensor(0.1859, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0156, dtype=torch.float64) <<
# tensor(0.1858, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch148 >> Training Loss: tensor(0.1858, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0155, dtype=torch.float64) <<
# tensor(0.1857, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch149 >> Training Loss: tensor(0.1857, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0155, dtype=torch.float64) <<
# tensor(0.1856, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch150 >> Training Loss: tensor(0.1856, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0155, dtype=torch.float64) <<
# tensor(0.1855, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch151 >> Training Loss: tensor(0.1855, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0155, dtype=torch.float64) <<
# tensor(0.1854, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch152 >> Training Loss: tensor(0.1854, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0155, dtype=torch.float64) <<
# tensor(0.1853, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch153 >> Training Loss: tensor(0.1853, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0155, dtype=torch.float64) <<
# tensor(0.1852, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch154 >> Training Loss: tensor(0.1852, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0155, dtype=torch.float64) <<
# tensor(0.1851, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch155 >> Training Loss: tensor(0.1851, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0154, dtype=torch.float64) <<
# tensor(0.1850, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch156 >> Training Loss: tensor(0.1850, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0154, dtype=torch.float64) <<
# tensor(0.1849, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch157 >> Training Loss: tensor(0.1849, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0154, dtype=torch.float64) <<
# tensor(0.1848, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch158 >> Training Loss: tensor(0.1848, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0154, dtype=torch.float64) <<
# tensor(0.1847, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch159 >> Training Loss: tensor(0.1847, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0154, dtype=torch.float64) <<
# tensor(0.1847, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch160 >> Training Loss: tensor(0.1847, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0154, dtype=torch.float64) <<
# tensor(0.1846, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch161 >> Training Loss: tensor(0.1846, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0154, dtype=torch.float64) <<
# tensor(0.1845, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch162 >> Training Loss: tensor(0.1845, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0153, dtype=torch.float64) <<
# tensor(0.1844, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch163 >> Training Loss: tensor(0.1844, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0153, dtype=torch.float64) <<
# tensor(0.1843, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch164 >> Training Loss: tensor(0.1843, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0153, dtype=torch.float64) <<
# tensor(0.1842, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch165 >> Training Loss: tensor(0.1842, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0153, dtype=torch.float64) <<
# tensor(0.1841, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch166 >> Training Loss: tensor(0.1841, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0153, dtype=torch.float64) <<
# tensor(0.1840, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch167 >> Training Loss: tensor(0.1840, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0153, dtype=torch.float64) <<
# tensor(0.1839, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch168 >> Training Loss: tensor(0.1839, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0153, dtype=torch.float64) <<
# tensor(0.1838, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch169 >> Training Loss: tensor(0.1838, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0153, dtype=torch.float64) <<
# tensor(0.1837, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch170 >> Training Loss: tensor(0.1837, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0152, dtype=torch.float64) <<
# tensor(0.1836, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch171 >> Training Loss: tensor(0.1836, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0152, dtype=torch.float64) <<
# tensor(0.1835, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch172 >> Training Loss: tensor(0.1835, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0152, dtype=torch.float64) <<
# tensor(0.1834, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch173 >> Training Loss: tensor(0.1834, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0152, dtype=torch.float64) <<
# tensor(0.1833, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch174 >> Training Loss: tensor(0.1833, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0152, dtype=torch.float64) <<
# tensor(0.1832, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch175 >> Training Loss: tensor(0.1832, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0152, dtype=torch.float64) <<
# tensor(0.1831, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch176 >> Training Loss: tensor(0.1831, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0152, dtype=torch.float64) <<
# tensor(0.1831, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch177 >> Training Loss: tensor(0.1831, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0151, dtype=torch.float64) <<
# tensor(0.1830, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch178 >> Training Loss: tensor(0.1830, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0151, dtype=torch.float64) <<
# tensor(0.1829, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch179 >> Training Loss: tensor(0.1829, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0151, dtype=torch.float64) <<
# tensor(0.1828, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch180 >> Training Loss: tensor(0.1828, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0151, dtype=torch.float64) <<
# tensor(0.1827, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch181 >> Training Loss: tensor(0.1827, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0151, dtype=torch.float64) <<
# tensor(0.1826, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch182 >> Training Loss: tensor(0.1826, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0151, dtype=torch.float64) <<
# tensor(0.1825, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch183 >> Training Loss: tensor(0.1825, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0151, dtype=torch.float64) <<
# tensor(0.1824, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch184 >> Training Loss: tensor(0.1824, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0150, dtype=torch.float64) <<
# tensor(0.1823, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch185 >> Training Loss: tensor(0.1823, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0150, dtype=torch.float64) <<
# tensor(0.1822, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch186 >> Training Loss: tensor(0.1822, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0150, dtype=torch.float64) <<
# tensor(0.1821, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch187 >> Training Loss: tensor(0.1821, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0150, dtype=torch.float64) <<
# tensor(0.1820, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch188 >> Training Loss: tensor(0.1820, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0150, dtype=torch.float64) <<
# tensor(0.1820, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch189 >> Training Loss: tensor(0.1820, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0150, dtype=torch.float64) <<
# tensor(0.1819, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch190 >> Training Loss: tensor(0.1819, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0150, dtype=torch.float64) <<
# tensor(0.1818, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch191 >> Training Loss: tensor(0.1818, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0150, dtype=torch.float64) <<
# tensor(0.1817, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch192 >> Training Loss: tensor(0.1817, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0149, dtype=torch.float64) <<
# tensor(0.1816, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch193 >> Training Loss: tensor(0.1816, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0149, dtype=torch.float64) <<
# tensor(0.1815, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch194 >> Training Loss: tensor(0.1815, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0149, dtype=torch.float64) <<
# tensor(0.1814, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch195 >> Training Loss: tensor(0.1814, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0149, dtype=torch.float64) <<
# tensor(0.1813, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch196 >> Training Loss: tensor(0.1813, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0149, dtype=torch.float64) <<
# tensor(0.1812, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch197 >> Training Loss: tensor(0.1812, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0149, dtype=torch.float64) <<
# tensor(0.1812, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch198 >> Training Loss: tensor(0.1812, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0149, dtype=torch.float64) <<
# tensor(0.1811, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch199 >> Training Loss: tensor(0.1811, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0149, dtype=torch.float64) <<
# tensor(0.1810, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch200 >> Training Loss: tensor(0.1810, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0148, dtype=torch.float64) <<
# tensor(0.1809, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch201 >> Training Loss: tensor(0.1809, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0148, dtype=torch.float64) <<
# tensor(0.1808, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch202 >> Training Loss: tensor(0.1808, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0148, dtype=torch.float64) <<
# tensor(0.1807, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch203 >> Training Loss: tensor(0.1807, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0148, dtype=torch.float64) <<
# tensor(0.1806, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch204 >> Training Loss: tensor(0.1806, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0148, dtype=torch.float64) <<
# tensor(0.1805, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch205 >> Training Loss: tensor(0.1805, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0148, dtype=torch.float64) <<
# tensor(0.1805, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch206 >> Training Loss: tensor(0.1805, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0148, dtype=torch.float64) <<
# tensor(0.1804, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch207 >> Training Loss: tensor(0.1804, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0148, dtype=torch.float64) <<
# tensor(0.1803, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch208 >> Training Loss: tensor(0.1803, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0147, dtype=torch.float64) <<
# tensor(0.1802, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch209 >> Training Loss: tensor(0.1802, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0147, dtype=torch.float64) <<
# tensor(0.1801, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch210 >> Training Loss: tensor(0.1801, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0147, dtype=torch.float64) <<
# tensor(0.1800, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch211 >> Training Loss: tensor(0.1800, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0147, dtype=torch.float64) <<
# tensor(0.1799, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch212 >> Training Loss: tensor(0.1799, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0147, dtype=torch.float64) <<
# tensor(0.1798, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch213 >> Training Loss: tensor(0.1798, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0147, dtype=torch.float64) <<
# tensor(0.1798, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch214 >> Training Loss: tensor(0.1798, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0147, dtype=torch.float64) <<
# tensor(0.1797, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch215 >> Training Loss: tensor(0.1797, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0147, dtype=torch.float64) <<
# tensor(0.1796, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch216 >> Training Loss: tensor(0.1796, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0146, dtype=torch.float64) <<
# tensor(0.1795, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch217 >> Training Loss: tensor(0.1795, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0146, dtype=torch.float64) <<
# tensor(0.1794, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch218 >> Training Loss: tensor(0.1794, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0146, dtype=torch.float64) <<
# tensor(0.1793, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch219 >> Training Loss: tensor(0.1793, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0146, dtype=torch.float64) <<
# tensor(0.1793, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch220 >> Training Loss: tensor(0.1793, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0146, dtype=torch.float64) <<
# tensor(0.1792, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch221 >> Training Loss: tensor(0.1792, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0146, dtype=torch.float64) <<
# tensor(0.1791, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch222 >> Training Loss: tensor(0.1791, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0146, dtype=torch.float64) <<
# tensor(0.1790, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch223 >> Training Loss: tensor(0.1790, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0146, dtype=torch.float64) <<
# tensor(0.1789, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch224 >> Training Loss: tensor(0.1789, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0145, dtype=torch.float64) <<
# tensor(0.1788, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch225 >> Training Loss: tensor(0.1788, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0145, dtype=torch.float64) <<
# tensor(0.1787, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch226 >> Training Loss: tensor(0.1787, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0145, dtype=torch.float64) <<
# tensor(0.1787, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch227 >> Training Loss: tensor(0.1787, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0145, dtype=torch.float64) <<
# tensor(0.1786, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch228 >> Training Loss: tensor(0.1786, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0145, dtype=torch.float64) <<
# tensor(0.1785, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch229 >> Training Loss: tensor(0.1785, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0145, dtype=torch.float64) <<
# tensor(0.1784, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch230 >> Training Loss: tensor(0.1784, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0145, dtype=torch.float64) <<
# tensor(0.1783, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch231 >> Training Loss: tensor(0.1783, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0145, dtype=torch.float64) <<
# tensor(0.1782, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch232 >> Training Loss: tensor(0.1782, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0144, dtype=torch.float64) <<
# tensor(0.1782, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch233 >> Training Loss: tensor(0.1782, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0144, dtype=torch.float64) <<
# tensor(0.1781, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch234 >> Training Loss: tensor(0.1781, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0144, dtype=torch.float64) <<
# tensor(0.1780, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch235 >> Training Loss: tensor(0.1780, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0144, dtype=torch.float64) <<
# tensor(0.1779, dtype=torch.float64, grad_fn=<AddBackward0>)
# ...
# Epoch421 >> Training Loss: tensor(0.1652, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1652, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch422 >> Training Loss: tensor(0.1652, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1651, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch423 >> Training Loss: tensor(0.1651, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1651, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch424 >> Training Loss: tensor(0.1651, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1650, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch425 >> Training Loss: tensor(0.1650, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1650, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch426 >> Training Loss: tensor(0.1650, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1649, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch427 >> Training Loss: tensor(0.1649, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1649, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch428 >> Training Loss: tensor(0.1649, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1648, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch429 >> Training Loss: tensor(0.1648, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1648, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch430 >> Training Loss: tensor(0.1648, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1647, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch431 >> Training Loss: tensor(0.1647, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1647, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch432 >> Training Loss: tensor(0.1647, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1646, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch433 >> Training Loss: tensor(0.1646, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1646, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch434 >> Training Loss: tensor(0.1646, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1645, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch435 >> Training Loss: tensor(0.1645, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1645, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch436 >> Training Loss: tensor(0.1645, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1644, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch437 >> Training Loss: tensor(0.1644, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1644, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch438 >> Training Loss: tensor(0.1644, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1643, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch439 >> Training Loss: tensor(0.1643, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1643, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch440 >> Training Loss: tensor(0.1643, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1642, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch441 >> Training Loss: tensor(0.1642, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1642, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch442 >> Training Loss: tensor(0.1642, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1641, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch443 >> Training Loss: tensor(0.1641, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1641, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch444 >> Training Loss: tensor(0.1641, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1640, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch445 >> Training Loss: tensor(0.1640, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1640, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch446 >> Training Loss: tensor(0.1640, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1639, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch447 >> Training Loss: tensor(0.1639, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1639, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch448 >> Training Loss: tensor(0.1639, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1639, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch449 >> Training Loss: tensor(0.1639, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1638, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch450 >> Training Loss: tensor(0.1638, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1638, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch451 >> Training Loss: tensor(0.1638, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1637, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch452 >> Training Loss: tensor(0.1637, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1637, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch453 >> Training Loss: tensor(0.1637, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1636, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch454 >> Training Loss: tensor(0.1636, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1636, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch455 >> Training Loss: tensor(0.1636, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1635, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch456 >> Training Loss: tensor(0.1635, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1635, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch457 >> Training Loss: tensor(0.1635, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1635, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch458 >> Training Loss: tensor(0.1635, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1634, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch459 >> Training Loss: tensor(0.1634, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1634, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch460 >> Training Loss: tensor(0.1634, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1633, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch461 >> Training Loss: tensor(0.1633, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1633, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch462 >> Training Loss: tensor(0.1633, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1633, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch463 >> Training Loss: tensor(0.1633, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1632, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch464 >> Training Loss: tensor(0.1632, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1632, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch465 >> Training Loss: tensor(0.1632, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1631, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch466 >> Training Loss: tensor(0.1631, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1631, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch467 >> Training Loss: tensor(0.1631, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1630, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch468 >> Training Loss: tensor(0.1630, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1630, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch469 >> Training Loss: tensor(0.1630, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1630, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch470 >> Training Loss: tensor(0.1630, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1629, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch471 >> Training Loss: tensor(0.1629, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1629, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch472 >> Training Loss: tensor(0.1629, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1629, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch473 >> Training Loss: tensor(0.1629, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1628, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch474 >> Training Loss: tensor(0.1628, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1628, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch475 >> Training Loss: tensor(0.1628, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1627, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch476 >> Training Loss: tensor(0.1627, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1627, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch477 >> Training Loss: tensor(0.1627, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1627, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch478 >> Training Loss: tensor(0.1627, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1626, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch479 >> Training Loss: tensor(0.1626, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1626, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch480 >> Training Loss: tensor(0.1626, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1626, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch481 >> Training Loss: tensor(0.1626, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1625, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch482 >> Training Loss: tensor(0.1625, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1625, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch483 >> Training Loss: tensor(0.1625, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1625, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch484 >> Training Loss: tensor(0.1625, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1624, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch485 >> Training Loss: tensor(0.1624, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1624, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch486 >> Training Loss: tensor(0.1624, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1624, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch487 >> Training Loss: tensor(0.1624, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1623, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch488 >> Training Loss: tensor(0.1623, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1623, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch489 >> Training Loss: tensor(0.1623, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1623, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch490 >> Training Loss: tensor(0.1623, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1622, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch491 >> Training Loss: tensor(0.1622, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1622, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch492 >> Training Loss: tensor(0.1622, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1622, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch493 >> Training Loss: tensor(0.1622, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1621, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch494 >> Training Loss: tensor(0.1621, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1621, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch495 >> Training Loss: tensor(0.1621, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1621, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch496 >> Training Loss: tensor(0.1621, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1620, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch497 >> Training Loss: tensor(0.1620, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1620, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch498 >> Training Loss: tensor(0.1620, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<
# tensor(0.1620, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch499 >> Training Loss: tensor(0.1620, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0128, dtype=torch.float64) <<

# %%
TRT_LOSS = []
for t in TR_LOSS:
    cc = t.detach().numpy()
    TRT_LOSS.append(cc)

# %%
plt.plot(TRT_LOSS)
plt.plot(VAL_LOSS)
plt.show()

# %%
accumulated_test_loss = 0.0
net.reset_hidden_states(bs=1)
it_test = iter(data_loaded.test_dataloader)
c=0
while c < int(X_test.shape[0]/1):
    #net.eval()
    with torch.set_grad_enabled(False):
        #print(c)
        c = c+1
        item = next(it_test)
        outputs = net(item[0])
        accumulated_test_loss = accumulated_test_loss + criterion(outputs, item[1])        
print(accumulated_test_loss/int(len(data_loaded.test_dataloader)))
# Out:
# tensor(0.0022, dtype=torch.float64)

# %%
import pandas as pd

# %%
#os.mkdir('RESULTS_LOSS')

# %%
tr_loss_array = []
for z in TR_LOSS:
    tr_loss_array.append(z.tolist())
training_loss = pd.DataFrame(tr_loss_array, columns=['TR_LOSS'])
training_loss.to_csv('../RESULTS_LOSS/TR_LOSS_'+str(output_cardinality)+'.csv')

# %%
val_loss_array = []
for z in VAL_LOSS:
    val_loss_array.append(z.tolist())
val_loss = pd.DataFrame(val_loss_array, columns=['VAL_LOSS'])
val_loss.to_csv('../RESULTS_LOSS/VAL_LOSS_'+str(output_cardinality)+'.csv')

# %%
test_loss_array = [accumulated_test_loss]

test2_loss = pd.DataFrame(test_loss_array, columns=['TEST_LOSS'])
test2_loss.to_csv('../RESULTS_LOSS/TEST_LOSS_'+str(output_cardinality)+'.csv')

# %%
# SAVE THE SCALER
import joblib
scaler_filename = "../SCALER_DUMPS/min_max_scaler_lookahead"+str(output_cardinality)+".save"
joblib.dump(scaler, scaler_filename) 
# And now to load...
# Out:
# ['../SCALER_DUMPS/min_max_scaler_lookahead6.save']

# %%
#SAVE MODEL
model_ckp_path = "../MODEL_CHECKPOINTS/model_lookahead"+str(output_cardinality)+".pth" 
torch.save(net.state_dict(), model_ckp_path)

# %%
#net2 = LSTMNET(batch_size=batch_size,input_len=input_cardinality,output_len=output_cardinality)
#net2.load_state_dict(torch.load(model_ckp_path))
#net2.eval()
#scaler = joblib.load(scaler_filename)
