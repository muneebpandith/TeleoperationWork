# %%
input_cardinality=20
output_cardinality=9

# %%
import torch
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import sklearn.model_selection as sk
import torch.autograd as autograd
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

# %%
#import pytorch_lightning as pl
import time
import copy
from tqdm import tqdm

# %%
torch.manual_seed(0)
def seed_worker(worker_id):
    worker_seed = torch.initial_seed() % 2**32
    np.random.seed(worker_seed)
    random.seed(worker_seed)

g = torch.Generator()
g.manual_seed(0)

# %%
#from pytorch_lightning.callbacks import ModelCheckpoint, EarlyStopping
#from pytorch_lightning.loggers import TensorBoardLogger

# %%
device = torch.device("cpu" if torch.cuda.is_available() else "cpu")

# %%
#pl.seed_everything(43)

# %%
class DATA:
    def __init__(self, data_path):
        self.data_path = data_path
        self.filenames = os.listdir(DATA_PATH)
        self.filenames = [filename for filename in self.filenames if filename.endswith(".csv")]
        self.len_filenames = len(self.filenames)
        
    def get_data(self):
        self.data = []
        for i in range(len(self.filenames)):
            self.data.append(self.read_data(i))
        return self.data
    
    def read_data(self,i):
        return pd.read_csv(self.data_path+"/"+self.filenames[i])
    

    def process_data(self, scaler, input_cardinality=20, output_cardinality=10, cols=['ThetaXHG']):
        self.datasamples = self.get_data()
        X = []
        y = []
        X_scaled = []
        y_scaled = []
        for i, datasample in enumerate(self.datasamples):            
            #for j in range(datasample[cols].shape[0]-output_cardinality):
            #    print('Input' +str(j)+ ' to '+str(j+input_cardinality) + 'Output: '+str(j+input_cardinality)+ ' to '+str(j+input_cardinality+output_cardinality))
            #Append to X (TO MAKE A LIST OF LISTS), [[0.019,1.02,...., upto input_cardinality]]
            #Append to Y (TO MAKE A LIST OF LISTS), [[0.019,1.02,...., upto output_cardinality]]
            #start of Y will be ahead of end of X by 1
            
            for j in range(datasample.shape[0]-output_cardinality-input_cardinality+1):
                X.append(datasample[cols].iloc[j:j+input_cardinality].to_numpy())
                y.append(datasample[cols].iloc[j+input_cardinality: j+input_cardinality+output_cardinality].to_numpy())
                X_scaled.append(scaler.transform(datasample[cols].iloc[j:j+input_cardinality].to_numpy()))
                y_scaled.append(scaler.transform(datasample[cols].iloc[j+input_cardinality: j+input_cardinality+output_cardinality].to_numpy()))
        
        #return self.datasamples, X, y
        #print(np.array(X).shape,np.array(y).shape,np.array(X_scaled).shape, np.array(y_scaled).shape)
        return self.datasamples, np.array(X), np.array(y), np.array(X_scaled), np.array(y_scaled)
    
    
    def train_test_split(self, X, y, split={'train':0.8,'val':0.2, 'test':0.5}):
        #print(X)
        self.X_train, self.X_val_test, self.y_train, self.y_val_test = sk.train_test_split(X, y, test_size=split['val'] , random_state=43)
        self.X_test, self.X_val, self.y_test, self.y_val = sk.train_test_split(self.X_val_test, self.y_val_test, test_size=split['test'] , random_state=43)
        
        return (self.X_train, self.y_train), (self.X_val, self.X_test), (self.X_test, self.y_test)
    
    
    
    def getscaler(self,cols):
        self.datasamples = self.get_data()       
        for i, sample in enumerate(self.datasamples):
            if i ==0:
                features = pd.DataFrame(sample[cols])
            else:
                features = pd.DataFrame.append(features, sample[cols]) #sample[cols]
   
        #scaling
        scaler = MinMaxScaler(feature_range=(-1,1))
        scaler = scaler.fit(features)
        features_scaled = pd.DataFrame(scaler.transform(features), index = features.index, columns = cols)
        return scaler
    
        """        
        #convert back to datasamples
        #save to X
        #save to X_scaled
        
        
        #Split treain test and validation
        
        for i in range(features.shape[0]):
            self.datasamples = []
            
        
        
        
        return features, features_scaled
        """

# %%
class THETADATASET(Dataset):
    #convert to pytorch dataset
    def __init__(self, X, y):
        self.X = X
        self.y = y
    def __len__(self):
        return len(self.X)
    def __getitem__(self, idx):
        sequence, output = self.X[idx], self.y[idx]
        return (torch.from_numpy(sequence.reshape(-1)), torch.from_numpy(output.reshape(-1)))
        #return dict(sequence=torch.tensor(sequence.reshape(-1),dtype=torch.float64), label=torch.tensor(output.reshape(-1),dtype=torch.float64))

# %%
class THETADATASETLOADER():
    def __init__(self, data, batchsize, bs_val):
        super().__init__()
        self.data = data
        self.batchsize = batchsize
        self.train_dataset = THETADATASET(self.data.X_train, self.data.y_train)
        self.val_dataset = THETADATASET(self.data.X_val, self.data.y_val)
        self.test_dataset = THETADATASET(self.data.X_test, self.data.y_test)
        self.train_dataloader = DataLoader(self.train_dataset, batch_size = self.batchsize, shuffle= False, num_workers=0, worker_init_fn=seed_worker,generator=g)
        self.val_dataloader = DataLoader(self.val_dataset, batch_size = bs_val, shuffle= False, num_workers=0,  worker_init_fn=seed_worker,generator=g)
        self.test_dataloader = DataLoader(self.test_dataset, batch_size = 1, shuffle= False, num_workers=0,  worker_init_fn=seed_worker,generator=g)

# %%
#dataloaders={}
#dataloaders['train'], dataloaders['val'] = data_loaded.train_dataloader, data_loaded.val_dataloader

# %%
"""
for f, o in tqdm(dataloaders['train']):
    #print(f[0].shape)
    break
"""
# Out:
# "\nfor f, o in tqdm(dataloaders['train']):\n    #print(f[0].shape)\n    break\n"

# %%
#loss_fn(a,first['label'])

# %%
#X_test.shape

# %%
def train_model(DATA_LOADED, model, criterion, optimizer, num_epochs=25):
    #train_model(DATA_LOADED, model, criterion, optimizer, scheduler, num_epochs=25):
    start = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_loss = 0
    dataloaders ={}
    dataloaders['train'], dataloaders['val'] = DATA_LOADED.train_dataloader, DATA_LOADED.val_dataloader

    #TR_ACCURACY=[]
    TR_LOSS=[]
    #VAL_ACCURACY=[]
    VAL_LOSS=[]
    for epoch in range(num_epochs):
        model.reset_hidden_states()
        #model.reset_hidden_states()
        #print(model.hidden)
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            #running_corrects = 0

            # Iterate over data.
            for inputs, labels in tqdm(dataloaders[phase]):
                inputs = inputs.to(device)
                labels = labels.to(device)

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    loss = criterion(outputs, labels)
                    #_, preds = torch.max(outputs, 1)
                # backward + optimize only if in training phase
                if phase == 'train':
                    optimizer.zero_grad()
                    loss.backward()
                    optimizer.step()

                # statistics
                running_loss += loss.item()
                #running_corrects += torch.sum(preds == labels.data)

            #if phase == 'train':
            #    scheduler.step()

            #epoch_loss = running_loss / DATA_LOADED.dataset_sizes[phase]
            epoch_loss = running_loss / dataset_size[phase]
            
            #epoch_acc = running_corrects.double() / DATA.dataset_sizes[phase]

            print('{} Loss: {:.4f}'.format(phase, epoch_loss))
            

            if phase == 'train':
                #  print("Training")
                #  TR_ACCURACY.append(epoch_acc)
                TR_LOSS.append(epoch_loss)
            else:
                print("Valuation")
                #VAL_ACCURACY.append(epoch_acc)
                VAL_LOSS.append(epoch_loss)

            # deep copy the model
            if phase == 'val' and epoch_loss < best_loss:
                best_loss = epoch_loss
                best_model_wts = copy.deepcopy(model.state_dict())


    time_elapsed = time.time() - start
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    #print('Best val Acc: {:4f}'.format(best_acc))

    model.load_state_dict(best_model_wts)
    return TR_LOSS, VAL_LOSS, model

# %%
class CHALLEABLELSTMNET(nn.Module):
    def __init__(self, batch_size, input_len, output_len, lstm_units = 4, num_layers=1):
        super(LSTMNET, self).__init__()
        self.input_len = input_len
        self.output_len = output_len
        self.num_layers = num_layers
        self.batch_size = batch_size
        #input_size = no of features = 1
        #hidden_size = no of lstm units in the layer
        #num_layers = no of lstm layers
        self.lstm_units = lstm_units
        self.lstm1 = nn.LSTM(input_size= 1, hidden_size= lstm_units, num_layers=num_layers,batch_first=True, dropout=0.6)
        
        self.linear0 = nn.Linear(in_features= 20, out_features=10)
        
        self.linear1 = nn.Linear(in_features= lstm_units, out_features=10)
        self.linear2 = nn.Linear(in_features= 10, out_features=10)
        self.ll = nn.Linear(in_features= 10, out_features=output_len)
        self.hidden = (torch.zeros(1*self.num_layers, self.batch_size, self.lstm_units).to(device).double(), torch.zeros(1*self.num_layers, self.batch_size, self.lstm_units).to(device).double())
        #print(self.hidden[0].device)
        #print(self.hidden.shape)
        #self.hidden[0]= self.hidden[0].to(device)
        #self.hidden[1] = self.hidden[1].to(device)
        self.tanh = nn.Tanh()
        self.sigmoid = nn.Sigmoid()
    def reset_hidden_states(self):
        self.hidden = (torch.zeros(1*self.num_layers, self.batch_size, self.lstm_units).double(), torch.zeros(1*self.num_layers, self.batch_size, self.lstm_units).double())
    def forward(self,x):
        #print(x.shape)
        #print(x)
        #print(x.unsqueeze(-1).shape)
        #print(self.hidden.shape)
        #print(self.hidden)
        #lstm_out, (h,c) = self.lstm1(x.unsqueeze(-1), self.hidden)
        #self.hidden= (h.detach(),c.detach())
        #c.detach_()
        #h.detach_()
        #self.hidden = (h.detach(), c.detach())
        #print(ht.shape)
        #ht=ht.to(device)
        #ct=ct.to(device)
        
        #lstm_out = lstm_out[:,-1,:]
        #print(ht.shape)
        #either lstm_out goes to next or ht goes
        #lstm_out= ht[-1]
        #lin1_out = self.linear1(lstm_out)
        #Add RELU
        lin0_out = F.relu(self.linear0(x))
        ll_out = self.ll(lin0_out)
        #x = self.linear0(x)
        #print(x.shape)
        
        #x = self.linear2(x)
        #Add RELU
        return ll_out

# %%
class LSTMNET(nn.Module):
    def __init__(self, batch_size, input_len, output_len, lstm_units = 4, num_layers=1):
        super(LSTMNET, self).__init__()
        self.input_len = input_len
        self.output_len = output_len
        self.num_layers = num_layers
        self.batch_size = batch_size
        #input_size = no of features = 1
        #hidden_size = no of lstm units in the layer
        #num_layers = no of lstm layers
        self.lstm_units = lstm_units
        self.lstm1 = nn.LSTM(input_size= 1, hidden_size= lstm_units, num_layers=num_layers,batch_first=True, dropout=0.6)
        
        self.linear0 = nn.Linear(in_features= 20, out_features=10)
        
        self.linear1 = nn.Linear(in_features= lstm_units, out_features=10)
        self.linear2 = nn.Linear(in_features= 10, out_features=10)
        self.ll = nn.Linear(in_features= 10, out_features=output_len)
        self.hidden = (torch.zeros(1*self.num_layers, self.batch_size, self.lstm_units).double(), torch.zeros(1*self.num_layers, self.batch_size, self.lstm_units).double())
        #print(self.hidden[0].device)
        #print(self.hidden.shape)
        #self.hidden[0]= self.hidden[0].to(device)
        #self.hidden[1] = self.hidden[1].to(device)
        self.tanh = nn.Tanh()
        self.sigmoid = nn.Sigmoid()
    
    def reset_hidden_states(self,bs):
        self.hidden = (torch.zeros(1*self.num_layers, bs, self.lstm_units).double(), torch.zeros(1*self.num_layers, bs, self.lstm_units).double())
        
    def forward(self,x):
        #print(x.shape)
        #print(x)
        #print(x.unsqueeze(-1).shape)
        #print(self.hidden.shape)
        #print(self.hidden)
        lstm_out, (h,c) = self.lstm1(x.unsqueeze(-1), self.hidden)
        self.hidden= (h.detach(),c.detach())
        #c.detach_()
        #h.detach_()
        #self.hidden = (h.detach(), c.detach())
        #print(ht.shape)
        #ht=ht.to(device)
        #ct=ct.to(device)
        
        lstm_out = lstm_out[:,-1,:]
        #print(ht.shape)
        #either lstm_out goes to next or ht goes
        #lstm_out= h.detach()[-1]
        lin1_out = self.linear1(lstm_out)
        #Add RELU
        #lin0_out = F.relu(self.linear0(x))
        ll_out = self.ll(lin1_out)
        #x = self.linear0(x)
        #print(x.shape)
        
        #x = self.linear2(x)
        #Add RELU
        return ll_out

# %%
#X_train.shape

# %%
epochs=500
batch_size = 16
bs_val = 16

# %%
# !ls
# Out:
# Lookahead10.ipynb  Lookahead2.ipynb  Lookahead6.ipynb  prediction.ipynb
# Lookahead15.ipynb  Lookahead3.ipynb  Lookahead7.ipynb  readme.md
# Lookahead1.ipynb   Lookahead4.ipynb  Lookahead8.ipynb
# Lookahead20.ipynb  Lookahead5.ipynb  Lookahead9.ipynb

# %%
DATA_PATH = "../DATASET/TRANSORMER_DATA"
data = DATA(DATA_PATH)
cols=['ThetaXHG']
scaler = data.getscaler(cols)

# %%
samples, X, y, X_scaled, y_scaled = data.process_data(scaler, input_cardinality=input_cardinality, output_cardinality=output_cardinality, cols=['ThetaXHG'])
(X_train, y_train), (X_val, y_val), (X_test, y_test) = data.train_test_split(X_scaled,y_scaled,  split={'train':0.8,'val':0.2, 'test':0.5})

# %%
y.shape
# Out:
# (968, 9, 1)

# %%
net = LSTMNET(batch_size=batch_size,input_len=input_cardinality,output_len=output_cardinality)
net = net.to(device)
net = net.double()
criterion = nn.MSELoss()
optimizer = optim.Adam(net.parameters(),lr=1e-1)
# Out:
# /home/toor/anaconda3/envs/py37/lib/python3.7/site-packages/torch/nn/modules/rnn.py:65: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.6 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))

# %%
#first['sequence'].double()

# %%
data_loaded = THETADATASETLOADER(data, batchsize=batch_size, bs_val = bs_val)

# %%
dataset_size={}
dataset_size['train'] =X_train.shape[0]
dataset_size['val'] =X_val.shape[0]
dataset_size['test'] =X_test.shape[0]

# %%
TR_LOSS = []
VAL_LOSS = []

# %%
722/16
# Out:
# 45.125

# %%
#Do separately Val loss and train loss
"""for i in range(epochs):
    net.reset_hidden_states(bs=batch_size)
    it = iter(data_loaded.train_dataloader)
    it_val = iter(data_loaded.train_dataloader)
    print('Epoch'+str(i))
    c = 0
    tr_loss = 0.0
    val_loss = 0.0
    
    while c < int(X_train.shape[0]/batch_size): 
        with torch.set_grad_enabled(True):
            #print(c)
            c = c+1
            item = next(it)
            outputs = net(item[0])
            tr_loss = tr_loss + criterion(outputs, item[1])
    
    TR_LOSS.append(tr_loss)
    print(tr_loss)
    optimizer.zero_grad()
    tr_loss.backward()
    optimizer.step()
    
    net.reset_hidden_states(bs=bs_val)
    #print(net.hidden[0].shape)
    while c < int(X_val.shape[0]/bs_val):
        net.eval()
        with torch.set_grad_enabled(False):
            #print(c)
            c = c+1
            item = next(it_val)
            outputs = net(item[0])
            val_loss = val_loss + criterion(outputs, item[1])
    VAL_LOSS.append(val_loss)
"""
# Out:
# "for i in range(epochs):\n    net.reset_hidden_states(bs=batch_size)\n    it = iter(data_loaded.train_dataloader)\n    it_val = iter(data_loaded.train_dataloader)\n    print('Epoch'+str(i))\n    c = 0\n    tr_loss = 0.0\n    val_loss = 0.0\n    \n    while c < int(X_train.shape[0]/batch_size): \n        with torch.set_grad_enabled(True):\n            #print(c)\n            c = c+1\n            item = next(it)\n            outputs = net(item[0])\n            tr_loss = tr_loss + criterion(outputs, item[1])\n    \n    TR_LOSS.append(tr_loss)\n    print(tr_loss)\n    optimizer.zero_grad()\n    tr_loss.backward()\n    optimizer.step()\n    \n    net.reset_hidden_states(bs=bs_val)\n    #print(net.hidden[0].shape)\n    while c < int(X_val.shape[0]/bs_val):\n        net.eval()\n        with torch.set_grad_enabled(False):\n            #print(c)\n            c = c+1\n            item = next(it_val)\n            outputs = net(item[0])\n            val_loss = val_loss + criterion(outputs, item[1])\n    VAL_LOSS.append(val_loss)\n"

# %%
#Do separately Val loss and train loss
TR_LOSS = []
VAL_LOSS = []
for i in range(epochs):
    net.train()
    net.reset_hidden_states(bs=batch_size)
    #print(net.hidden[0].shape)
    it = iter(data_loaded.train_dataloader)
    it_val = iter(data_loaded.train_dataloader)
    c = 0
    tr_loss = 0.0
    val_loss = 0.0
    while c < int(X_train.shape[0]/batch_size): 
        with torch.set_grad_enabled(True):
            #print(c)
            c = c+1
            item = next(it)
            inputs = item[0].to(device)
            labels = item[1].to(device)
            
            outputs = net(inputs)
            tr_loss = tr_loss + criterion(outputs, labels)
    
    TR_LOSS.append(tr_loss)
    print(tr_loss)
    optimizer.zero_grad()
    tr_loss.backward()
    optimizer.step()
    c = 0
    
    #net.reset_hidden_states(bs=bs_val)
    #print(net.hidden[0].shape)
    #print(net.hidden[0].shape)
    while c < int(X_val.shape[0]/bs_val):
        net.eval()
        with torch.set_grad_enabled(False):
            #print(c)
            c = c+1
            item = next(it_val)
            inputs = item[0].to(device)
            labels = item[1].to(device)
            
            outputs = net(inputs)
            val_loss = val_loss + criterion(outputs, labels)
            #print(val_loss)
    VAL_LOSS.append(val_loss)
    print('Epoch'+str(i)+ ' >> Training Loss: '+str(tr_loss)+ ' Validation Loss: '+str(val_loss)+ ' <<')
# Out:
# tensor(16.2273, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch0 >> Training Loss: tensor(16.2273, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.7617, dtype=torch.float64) <<
# tensor(6.5735, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch1 >> Training Loss: tensor(6.5735, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.7919, dtype=torch.float64) <<
# tensor(6.9171, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch2 >> Training Loss: tensor(6.9171, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.8428, dtype=torch.float64) <<
# tensor(6.5723, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch3 >> Training Loss: tensor(6.5723, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.6911, dtype=torch.float64) <<
# tensor(5.5109, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch4 >> Training Loss: tensor(5.5109, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.6632, dtype=torch.float64) <<
# tensor(5.6320, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch5 >> Training Loss: tensor(5.6320, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.6327, dtype=torch.float64) <<
# tensor(5.3480, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch6 >> Training Loss: tensor(5.3480, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.6153, dtype=torch.float64) <<
# tensor(4.9640, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch7 >> Training Loss: tensor(4.9640, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.5684, dtype=torch.float64) <<
# tensor(4.5508, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch8 >> Training Loss: tensor(4.5508, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.4508, dtype=torch.float64) <<
# tensor(3.7913, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch9 >> Training Loss: tensor(3.7913, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.4029, dtype=torch.float64) <<
# tensor(3.5122, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch10 >> Training Loss: tensor(3.5122, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.3138, dtype=torch.float64) <<
# tensor(2.6617, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch11 >> Training Loss: tensor(2.6617, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.2554, dtype=torch.float64) <<
# tensor(2.0407, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch12 >> Training Loss: tensor(2.0407, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.1307, dtype=torch.float64) <<
# tensor(1.0959, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch13 >> Training Loss: tensor(1.0959, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.1573, dtype=torch.float64) <<
# tensor(1.3276, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch14 >> Training Loss: tensor(1.3276, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.2166, dtype=torch.float64) <<
# tensor(1.9105, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch15 >> Training Loss: tensor(1.9105, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.1508, dtype=torch.float64) <<
# tensor(1.3075, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch16 >> Training Loss: tensor(1.3075, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.1618, dtype=torch.float64) <<
# tensor(1.3456, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch17 >> Training Loss: tensor(1.3456, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0775, dtype=torch.float64) <<
# tensor(0.6869, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch18 >> Training Loss: tensor(0.6869, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0903, dtype=torch.float64) <<
# tensor(0.7580, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch19 >> Training Loss: tensor(0.7580, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0617, dtype=torch.float64) <<
# tensor(0.5426, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch20 >> Training Loss: tensor(0.5426, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0788, dtype=torch.float64) <<
# tensor(0.7301, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch21 >> Training Loss: tensor(0.7301, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0802, dtype=torch.float64) <<
# tensor(0.7412, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch22 >> Training Loss: tensor(0.7412, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0814, dtype=torch.float64) <<
# tensor(0.6976, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch23 >> Training Loss: tensor(0.6976, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.1002, dtype=torch.float64) <<
# tensor(0.8162, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch24 >> Training Loss: tensor(0.8162, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0837, dtype=torch.float64) <<
# tensor(0.7087, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch25 >> Training Loss: tensor(0.7087, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0733, dtype=torch.float64) <<
# tensor(0.6702, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch26 >> Training Loss: tensor(0.6702, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0720, dtype=torch.float64) <<
# tensor(0.6666, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch27 >> Training Loss: tensor(0.6666, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0595, dtype=torch.float64) <<
# tensor(0.5362, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch28 >> Training Loss: tensor(0.5362, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0681, dtype=torch.float64) <<
# tensor(0.5887, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch29 >> Training Loss: tensor(0.5887, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0623, dtype=torch.float64) <<
# tensor(0.5516, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch30 >> Training Loss: tensor(0.5516, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0635, dtype=torch.float64) <<
# tensor(0.5732, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch31 >> Training Loss: tensor(0.5732, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0676, dtype=torch.float64) <<
# tensor(0.6066, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch32 >> Training Loss: tensor(0.6066, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0605, dtype=torch.float64) <<
# tensor(0.5476, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch33 >> Training Loss: tensor(0.5476, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0623, dtype=torch.float64) <<
# tensor(0.5599, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch34 >> Training Loss: tensor(0.5599, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0504, dtype=torch.float64) <<
# tensor(0.4638, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch35 >> Training Loss: tensor(0.4638, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0502, dtype=torch.float64) <<
# tensor(0.4676, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch36 >> Training Loss: tensor(0.4676, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0450, dtype=torch.float64) <<
# tensor(0.4203, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch37 >> Training Loss: tensor(0.4203, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0477, dtype=torch.float64) <<
# tensor(0.4288, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch38 >> Training Loss: tensor(0.4288, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0494, dtype=torch.float64) <<
# tensor(0.4395, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch39 >> Training Loss: tensor(0.4395, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0471, dtype=torch.float64) <<
# tensor(0.4325, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch40 >> Training Loss: tensor(0.4325, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0492, dtype=torch.float64) <<
# tensor(0.4558, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch41 >> Training Loss: tensor(0.4558, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0468, dtype=torch.float64) <<
# tensor(0.4267, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch42 >> Training Loss: tensor(0.4267, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0489, dtype=torch.float64) <<
# tensor(0.4367, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch43 >> Training Loss: tensor(0.4367, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0446, dtype=torch.float64) <<
# tensor(0.4090, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch44 >> Training Loss: tensor(0.4090, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0441, dtype=torch.float64) <<
# tensor(0.4137, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch45 >> Training Loss: tensor(0.4137, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0432, dtype=torch.float64) <<
# tensor(0.4068, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch46 >> Training Loss: tensor(0.4068, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0442, dtype=torch.float64) <<
# tensor(0.4144, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch47 >> Training Loss: tensor(0.4144, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0444, dtype=torch.float64) <<
# tensor(0.4184, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch48 >> Training Loss: tensor(0.4184, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0441, dtype=torch.float64) <<
# tensor(0.4183, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch49 >> Training Loss: tensor(0.4183, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0437, dtype=torch.float64) <<
# tensor(0.4157, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch50 >> Training Loss: tensor(0.4157, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0428, dtype=torch.float64) <<
# tensor(0.4055, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch51 >> Training Loss: tensor(0.4055, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0424, dtype=torch.float64) <<
# tensor(0.4009, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch52 >> Training Loss: tensor(0.4009, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0414, dtype=torch.float64) <<
# tensor(0.3933, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch53 >> Training Loss: tensor(0.3933, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0416, dtype=torch.float64) <<
# tensor(0.3952, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch54 >> Training Loss: tensor(0.3952, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0419, dtype=torch.float64) <<
# tensor(0.3923, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch55 >> Training Loss: tensor(0.3923, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0426, dtype=torch.float64) <<
# tensor(0.3964, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch56 >> Training Loss: tensor(0.3964, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0416, dtype=torch.float64) <<
# tensor(0.3921, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch57 >> Training Loss: tensor(0.3921, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0415, dtype=torch.float64) <<
# tensor(0.3938, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch58 >> Training Loss: tensor(0.3938, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0412, dtype=torch.float64) <<
# tensor(0.3879, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch59 >> Training Loss: tensor(0.3879, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0414, dtype=torch.float64) <<
# tensor(0.3890, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch60 >> Training Loss: tensor(0.3890, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0403, dtype=torch.float64) <<
# tensor(0.3847, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch61 >> Training Loss: tensor(0.3847, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0404, dtype=torch.float64) <<
# tensor(0.3871, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch62 >> Training Loss: tensor(0.3871, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0403, dtype=torch.float64) <<
# tensor(0.3850, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch63 >> Training Loss: tensor(0.3850, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0406, dtype=torch.float64) <<
# tensor(0.3871, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch64 >> Training Loss: tensor(0.3871, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0402, dtype=torch.float64) <<
# tensor(0.3851, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch65 >> Training Loss: tensor(0.3851, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0402, dtype=torch.float64) <<
# tensor(0.3852, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch66 >> Training Loss: tensor(0.3852, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0403, dtype=torch.float64) <<
# tensor(0.3830, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch67 >> Training Loss: tensor(0.3830, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0403, dtype=torch.float64) <<
# tensor(0.3821, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch68 >> Training Loss: tensor(0.3821, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0400, dtype=torch.float64) <<
# tensor(0.3810, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch69 >> Training Loss: tensor(0.3810, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0401, dtype=torch.float64) <<
# tensor(0.3806, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch70 >> Training Loss: tensor(0.3806, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0405, dtype=torch.float64) <<
# tensor(0.3808, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch71 >> Training Loss: tensor(0.3808, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0404, dtype=torch.float64) <<
# tensor(0.3803, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch72 >> Training Loss: tensor(0.3803, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0402, dtype=torch.float64) <<
# tensor(0.3807, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch73 >> Training Loss: tensor(0.3807, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0402, dtype=torch.float64) <<
# tensor(0.3795, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch74 >> Training Loss: tensor(0.3795, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0404, dtype=torch.float64) <<
# tensor(0.3796, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch75 >> Training Loss: tensor(0.3796, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0401, dtype=torch.float64) <<
# tensor(0.3782, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch76 >> Training Loss: tensor(0.3782, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0399, dtype=torch.float64) <<
# tensor(0.3786, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch77 >> Training Loss: tensor(0.3786, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0399, dtype=torch.float64) <<
# tensor(0.3777, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch78 >> Training Loss: tensor(0.3777, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0400, dtype=torch.float64) <<
# tensor(0.3783, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch79 >> Training Loss: tensor(0.3783, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0398, dtype=torch.float64) <<
# tensor(0.3776, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch80 >> Training Loss: tensor(0.3776, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0397, dtype=torch.float64) <<
# tensor(0.3776, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch81 >> Training Loss: tensor(0.3776, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0398, dtype=torch.float64) <<
# tensor(0.3769, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch82 >> Training Loss: tensor(0.3769, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0397, dtype=torch.float64) <<
# tensor(0.3763, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch83 >> Training Loss: tensor(0.3763, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0396, dtype=torch.float64) <<
# tensor(0.3760, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch84 >> Training Loss: tensor(0.3760, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0396, dtype=torch.float64) <<
# tensor(0.3755, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch85 >> Training Loss: tensor(0.3755, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0398, dtype=torch.float64) <<
# tensor(0.3757, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch86 >> Training Loss: tensor(0.3757, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0396, dtype=torch.float64) <<
# tensor(0.3753, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch87 >> Training Loss: tensor(0.3753, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0396, dtype=torch.float64) <<
# tensor(0.3753, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch88 >> Training Loss: tensor(0.3753, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0396, dtype=torch.float64) <<
# tensor(0.3748, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch89 >> Training Loss: tensor(0.3748, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0395, dtype=torch.float64) <<
# tensor(0.3745, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch90 >> Training Loss: tensor(0.3745, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0394, dtype=torch.float64) <<
# tensor(0.3743, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch91 >> Training Loss: tensor(0.3743, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0394, dtype=torch.float64) <<
# tensor(0.3741, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch92 >> Training Loss: tensor(0.3741, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0394, dtype=torch.float64) <<
# tensor(0.3741, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch93 >> Training Loss: tensor(0.3741, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0393, dtype=torch.float64) <<
# tensor(0.3738, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch94 >> Training Loss: tensor(0.3738, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0393, dtype=torch.float64) <<
# tensor(0.3736, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch95 >> Training Loss: tensor(0.3736, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0393, dtype=torch.float64) <<
# tensor(0.3733, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch96 >> Training Loss: tensor(0.3733, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0393, dtype=torch.float64) <<
# tensor(0.3730, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch97 >> Training Loss: tensor(0.3730, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0393, dtype=torch.float64) <<
# tensor(0.3729, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch98 >> Training Loss: tensor(0.3729, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0393, dtype=torch.float64) <<
# tensor(0.3726, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch99 >> Training Loss: tensor(0.3726, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0393, dtype=torch.float64) <<
# tensor(0.3724, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch100 >> Training Loss: tensor(0.3724, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0393, dtype=torch.float64) <<
# tensor(0.3722, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch101 >> Training Loss: tensor(0.3722, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0393, dtype=torch.float64) <<
# tensor(0.3720, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch102 >> Training Loss: tensor(0.3720, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0393, dtype=torch.float64) <<
# tensor(0.3718, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch103 >> Training Loss: tensor(0.3718, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0392, dtype=torch.float64) <<
# tensor(0.3715, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch104 >> Training Loss: tensor(0.3715, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0392, dtype=torch.float64) <<
# tensor(0.3714, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch105 >> Training Loss: tensor(0.3714, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0392, dtype=torch.float64) <<
# tensor(0.3712, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch106 >> Training Loss: tensor(0.3712, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0392, dtype=torch.float64) <<
# tensor(0.3710, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch107 >> Training Loss: tensor(0.3710, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0391, dtype=torch.float64) <<
# tensor(0.3708, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch108 >> Training Loss: tensor(0.3708, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0391, dtype=torch.float64) <<
# tensor(0.3706, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch109 >> Training Loss: tensor(0.3706, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0391, dtype=torch.float64) <<
# tensor(0.3704, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch110 >> Training Loss: tensor(0.3704, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0391, dtype=torch.float64) <<
# tensor(0.3702, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch111 >> Training Loss: tensor(0.3702, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0391, dtype=torch.float64) <<
# tensor(0.3700, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch112 >> Training Loss: tensor(0.3700, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0391, dtype=torch.float64) <<
# tensor(0.3698, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch113 >> Training Loss: tensor(0.3698, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0391, dtype=torch.float64) <<
# tensor(0.3696, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch114 >> Training Loss: tensor(0.3696, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0391, dtype=torch.float64) <<
# tensor(0.3694, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch115 >> Training Loss: tensor(0.3694, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0391, dtype=torch.float64) <<
# tensor(0.3692, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch116 >> Training Loss: tensor(0.3692, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0390, dtype=torch.float64) <<
# tensor(0.3690, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch117 >> Training Loss: tensor(0.3690, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0390, dtype=torch.float64) <<
# tensor(0.3688, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch118 >> Training Loss: tensor(0.3688, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0390, dtype=torch.float64) <<
# tensor(0.3687, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch119 >> Training Loss: tensor(0.3687, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0389, dtype=torch.float64) <<
# tensor(0.3685, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch120 >> Training Loss: tensor(0.3685, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0389, dtype=torch.float64) <<
# tensor(0.3683, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch121 >> Training Loss: tensor(0.3683, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0389, dtype=torch.float64) <<
# tensor(0.3681, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch122 >> Training Loss: tensor(0.3681, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0389, dtype=torch.float64) <<
# tensor(0.3679, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch123 >> Training Loss: tensor(0.3679, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0389, dtype=torch.float64) <<
# tensor(0.3677, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch124 >> Training Loss: tensor(0.3677, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0389, dtype=torch.float64) <<
# tensor(0.3675, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch125 >> Training Loss: tensor(0.3675, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0389, dtype=torch.float64) <<
# tensor(0.3673, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch126 >> Training Loss: tensor(0.3673, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0389, dtype=torch.float64) <<
# tensor(0.3672, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch127 >> Training Loss: tensor(0.3672, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0389, dtype=torch.float64) <<
# tensor(0.3670, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch128 >> Training Loss: tensor(0.3670, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0388, dtype=torch.float64) <<
# tensor(0.3668, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch129 >> Training Loss: tensor(0.3668, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0388, dtype=torch.float64) <<
# tensor(0.3666, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch130 >> Training Loss: tensor(0.3666, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0388, dtype=torch.float64) <<
# tensor(0.3664, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch131 >> Training Loss: tensor(0.3664, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0388, dtype=torch.float64) <<
# tensor(0.3662, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch132 >> Training Loss: tensor(0.3662, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0388, dtype=torch.float64) <<
# tensor(0.3661, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch133 >> Training Loss: tensor(0.3661, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0388, dtype=torch.float64) <<
# tensor(0.3659, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch134 >> Training Loss: tensor(0.3659, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0387, dtype=torch.float64) <<
# tensor(0.3657, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch135 >> Training Loss: tensor(0.3657, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0387, dtype=torch.float64) <<
# tensor(0.3655, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch136 >> Training Loss: tensor(0.3655, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0387, dtype=torch.float64) <<
# tensor(0.3653, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch137 >> Training Loss: tensor(0.3653, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0387, dtype=torch.float64) <<
# tensor(0.3651, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch138 >> Training Loss: tensor(0.3651, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0387, dtype=torch.float64) <<
# tensor(0.3649, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch139 >> Training Loss: tensor(0.3649, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0387, dtype=torch.float64) <<
# tensor(0.3648, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch140 >> Training Loss: tensor(0.3648, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0387, dtype=torch.float64) <<
# tensor(0.3646, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch141 >> Training Loss: tensor(0.3646, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0387, dtype=torch.float64) <<
# tensor(0.3644, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch142 >> Training Loss: tensor(0.3644, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0386, dtype=torch.float64) <<
# tensor(0.3642, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch143 >> Training Loss: tensor(0.3642, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0386, dtype=torch.float64) <<
# tensor(0.3640, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch144 >> Training Loss: tensor(0.3640, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0386, dtype=torch.float64) <<
# tensor(0.3639, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch145 >> Training Loss: tensor(0.3639, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0386, dtype=torch.float64) <<
# tensor(0.3637, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch146 >> Training Loss: tensor(0.3637, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0386, dtype=torch.float64) <<
# tensor(0.3635, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch147 >> Training Loss: tensor(0.3635, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0386, dtype=torch.float64) <<
# tensor(0.3633, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch148 >> Training Loss: tensor(0.3633, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0385, dtype=torch.float64) <<
# tensor(0.3631, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch149 >> Training Loss: tensor(0.3631, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0385, dtype=torch.float64) <<
# tensor(0.3629, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch150 >> Training Loss: tensor(0.3629, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0385, dtype=torch.float64) <<
# tensor(0.3628, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch151 >> Training Loss: tensor(0.3628, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0385, dtype=torch.float64) <<
# tensor(0.3626, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch152 >> Training Loss: tensor(0.3626, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0385, dtype=torch.float64) <<
# tensor(0.3624, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch153 >> Training Loss: tensor(0.3624, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0385, dtype=torch.float64) <<
# tensor(0.3622, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch154 >> Training Loss: tensor(0.3622, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0385, dtype=torch.float64) <<
# tensor(0.3620, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch155 >> Training Loss: tensor(0.3620, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0385, dtype=torch.float64) <<
# tensor(0.3619, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch156 >> Training Loss: tensor(0.3619, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0384, dtype=torch.float64) <<
# tensor(0.3617, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch157 >> Training Loss: tensor(0.3617, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0384, dtype=torch.float64) <<
# tensor(0.3615, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch158 >> Training Loss: tensor(0.3615, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0384, dtype=torch.float64) <<
# tensor(0.3613, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch159 >> Training Loss: tensor(0.3613, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0384, dtype=torch.float64) <<
# tensor(0.3611, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch160 >> Training Loss: tensor(0.3611, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0384, dtype=torch.float64) <<
# tensor(0.3610, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch161 >> Training Loss: tensor(0.3610, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0384, dtype=torch.float64) <<
# tensor(0.3608, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch162 >> Training Loss: tensor(0.3608, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0384, dtype=torch.float64) <<
# tensor(0.3606, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch163 >> Training Loss: tensor(0.3606, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0384, dtype=torch.float64) <<
# tensor(0.3604, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch164 >> Training Loss: tensor(0.3604, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0383, dtype=torch.float64) <<
# tensor(0.3602, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch165 >> Training Loss: tensor(0.3602, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0383, dtype=torch.float64) <<
# tensor(0.3601, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch166 >> Training Loss: tensor(0.3601, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0383, dtype=torch.float64) <<
# tensor(0.3599, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch167 >> Training Loss: tensor(0.3599, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0383, dtype=torch.float64) <<
# tensor(0.3597, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch168 >> Training Loss: tensor(0.3597, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0383, dtype=torch.float64) <<
# tensor(0.3595, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch169 >> Training Loss: tensor(0.3595, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0383, dtype=torch.float64) <<
# tensor(0.3593, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch170 >> Training Loss: tensor(0.3593, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0383, dtype=torch.float64) <<
# tensor(0.3592, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch171 >> Training Loss: tensor(0.3592, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0382, dtype=torch.float64) <<
# tensor(0.3590, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch172 >> Training Loss: tensor(0.3590, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0382, dtype=torch.float64) <<
# tensor(0.3588, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch173 >> Training Loss: tensor(0.3588, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0382, dtype=torch.float64) <<
# tensor(0.3586, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch174 >> Training Loss: tensor(0.3586, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0382, dtype=torch.float64) <<
# tensor(0.3585, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch175 >> Training Loss: tensor(0.3585, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0382, dtype=torch.float64) <<
# tensor(0.3583, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch176 >> Training Loss: tensor(0.3583, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0382, dtype=torch.float64) <<
# tensor(0.3581, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch177 >> Training Loss: tensor(0.3581, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0382, dtype=torch.float64) <<
# tensor(0.3579, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch178 >> Training Loss: tensor(0.3579, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0382, dtype=torch.float64) <<
# tensor(0.3577, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch179 >> Training Loss: tensor(0.3577, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0381, dtype=torch.float64) <<
# tensor(0.3576, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch180 >> Training Loss: tensor(0.3576, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0381, dtype=torch.float64) <<
# tensor(0.3574, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch181 >> Training Loss: tensor(0.3574, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0381, dtype=torch.float64) <<
# tensor(0.3572, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch182 >> Training Loss: tensor(0.3572, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0381, dtype=torch.float64) <<
# tensor(0.3570, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch183 >> Training Loss: tensor(0.3570, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0381, dtype=torch.float64) <<
# tensor(0.3568, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch184 >> Training Loss: tensor(0.3568, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0381, dtype=torch.float64) <<
# tensor(0.3567, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch185 >> Training Loss: tensor(0.3567, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0381, dtype=torch.float64) <<
# tensor(0.3565, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch186 >> Training Loss: tensor(0.3565, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0380, dtype=torch.float64) <<
# tensor(0.3563, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch187 >> Training Loss: tensor(0.3563, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0380, dtype=torch.float64) <<
# tensor(0.3561, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch188 >> Training Loss: tensor(0.3561, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0380, dtype=torch.float64) <<
# tensor(0.3559, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch189 >> Training Loss: tensor(0.3559, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0380, dtype=torch.float64) <<
# tensor(0.3558, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch190 >> Training Loss: tensor(0.3558, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0380, dtype=torch.float64) <<
# tensor(0.3556, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch191 >> Training Loss: tensor(0.3556, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0380, dtype=torch.float64) <<
# tensor(0.3554, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch192 >> Training Loss: tensor(0.3554, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0380, dtype=torch.float64) <<
# tensor(0.3552, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch193 >> Training Loss: tensor(0.3552, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0380, dtype=torch.float64) <<
# tensor(0.3550, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch194 >> Training Loss: tensor(0.3550, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0379, dtype=torch.float64) <<
# tensor(0.3549, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch195 >> Training Loss: tensor(0.3549, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0379, dtype=torch.float64) <<
# tensor(0.3547, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch196 >> Training Loss: tensor(0.3547, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0379, dtype=torch.float64) <<
# tensor(0.3545, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch197 >> Training Loss: tensor(0.3545, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0379, dtype=torch.float64) <<
# tensor(0.3543, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch198 >> Training Loss: tensor(0.3543, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0379, dtype=torch.float64) <<
# tensor(0.3541, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch199 >> Training Loss: tensor(0.3541, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0379, dtype=torch.float64) <<
# tensor(0.3540, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch200 >> Training Loss: tensor(0.3540, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0379, dtype=torch.float64) <<
# tensor(0.3538, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch201 >> Training Loss: tensor(0.3538, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0378, dtype=torch.float64) <<
# tensor(0.3536, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch202 >> Training Loss: tensor(0.3536, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0378, dtype=torch.float64) <<
# tensor(0.3534, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch203 >> Training Loss: tensor(0.3534, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0378, dtype=torch.float64) <<
# tensor(0.3532, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch204 >> Training Loss: tensor(0.3532, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0378, dtype=torch.float64) <<
# tensor(0.3530, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch205 >> Training Loss: tensor(0.3530, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0378, dtype=torch.float64) <<
# tensor(0.3529, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch206 >> Training Loss: tensor(0.3529, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0378, dtype=torch.float64) <<
# tensor(0.3527, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch207 >> Training Loss: tensor(0.3527, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0378, dtype=torch.float64) <<
# tensor(0.3525, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch208 >> Training Loss: tensor(0.3525, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0377, dtype=torch.float64) <<
# tensor(0.3523, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch209 >> Training Loss: tensor(0.3523, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0377, dtype=torch.float64) <<
# tensor(0.3521, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch210 >> Training Loss: tensor(0.3521, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0377, dtype=torch.float64) <<
# tensor(0.3520, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch211 >> Training Loss: tensor(0.3520, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0377, dtype=torch.float64) <<
# tensor(0.3518, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch212 >> Training Loss: tensor(0.3518, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0377, dtype=torch.float64) <<
# tensor(0.3516, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch213 >> Training Loss: tensor(0.3516, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0377, dtype=torch.float64) <<
# tensor(0.3514, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch214 >> Training Loss: tensor(0.3514, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0377, dtype=torch.float64) <<
# tensor(0.3512, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch215 >> Training Loss: tensor(0.3512, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0376, dtype=torch.float64) <<
# tensor(0.3510, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch216 >> Training Loss: tensor(0.3510, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0376, dtype=torch.float64) <<
# tensor(0.3509, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch217 >> Training Loss: tensor(0.3509, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0376, dtype=torch.float64) <<
# tensor(0.3507, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch218 >> Training Loss: tensor(0.3507, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0376, dtype=torch.float64) <<
# tensor(0.3505, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch219 >> Training Loss: tensor(0.3505, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0376, dtype=torch.float64) <<
# tensor(0.3503, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch220 >> Training Loss: tensor(0.3503, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0376, dtype=torch.float64) <<
# tensor(0.3501, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch221 >> Training Loss: tensor(0.3501, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0376, dtype=torch.float64) <<
# tensor(0.3499, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch222 >> Training Loss: tensor(0.3499, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0375, dtype=torch.float64) <<
# tensor(0.3497, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch223 >> Training Loss: tensor(0.3497, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0375, dtype=torch.float64) <<
# tensor(0.3496, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch224 >> Training Loss: tensor(0.3496, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0375, dtype=torch.float64) <<
# tensor(0.3494, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch225 >> Training Loss: tensor(0.3494, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0375, dtype=torch.float64) <<
# tensor(0.3492, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch226 >> Training Loss: tensor(0.3492, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0375, dtype=torch.float64) <<
# tensor(0.3490, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch227 >> Training Loss: tensor(0.3490, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0375, dtype=torch.float64) <<
# tensor(0.3489, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch228 >> Training Loss: tensor(0.3489, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0374, dtype=torch.float64) <<
# tensor(0.3487, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch229 >> Training Loss: tensor(0.3487, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0375, dtype=torch.float64) <<
# tensor(0.3487, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch230 >> Training Loss: tensor(0.3487, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0374, dtype=torch.float64) <<
# tensor(0.3489, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch231 >> Training Loss: tensor(0.3489, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0377, dtype=torch.float64) <<
# tensor(0.3495, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch232 >> Training Loss: tensor(0.3495, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0377, dtype=torch.float64) <<
# tensor(0.3516, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch233 >> Training Loss: tensor(0.3516, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0389, dtype=torch.float64) <<
# tensor(0.3573, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch234 >> Training Loss: tensor(0.3573, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0400, dtype=torch.float64) <<
# tensor(0.3725, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch235 >> Training Loss: tensor(0.3725, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0463, dtype=torch.float64) <<
# tensor(0.4125, dtype=torch.float64, grad_fn=<AddBackward0>)
# ...
# Epoch421 >> Training Loss: tensor(0.3542, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0397, dtype=torch.float64) <<
# tensor(0.3526, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch422 >> Training Loss: tensor(0.3526, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0398, dtype=torch.float64) <<
# tensor(0.3532, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch423 >> Training Loss: tensor(0.3532, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0394, dtype=torch.float64) <<
# tensor(0.3518, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch424 >> Training Loss: tensor(0.3518, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0393, dtype=torch.float64) <<
# tensor(0.3521, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch425 >> Training Loss: tensor(0.3521, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0393, dtype=torch.float64) <<
# tensor(0.3510, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch426 >> Training Loss: tensor(0.3510, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0392, dtype=torch.float64) <<
# tensor(0.3510, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch427 >> Training Loss: tensor(0.3510, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0390, dtype=torch.float64) <<
# tensor(0.3502, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch428 >> Training Loss: tensor(0.3502, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0389, dtype=torch.float64) <<
# tensor(0.3499, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch429 >> Training Loss: tensor(0.3499, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0390, dtype=torch.float64) <<
# tensor(0.3493, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch430 >> Training Loss: tensor(0.3493, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0389, dtype=torch.float64) <<
# tensor(0.3488, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch431 >> Training Loss: tensor(0.3488, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0388, dtype=torch.float64) <<
# tensor(0.3484, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch432 >> Training Loss: tensor(0.3484, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0387, dtype=torch.float64) <<
# tensor(0.3478, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch433 >> Training Loss: tensor(0.3478, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0387, dtype=torch.float64) <<
# tensor(0.3474, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch434 >> Training Loss: tensor(0.3474, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0386, dtype=torch.float64) <<
# tensor(0.3467, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch435 >> Training Loss: tensor(0.3467, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0384, dtype=torch.float64) <<
# tensor(0.3466, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch436 >> Training Loss: tensor(0.3466, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0383, dtype=torch.float64) <<
# tensor(0.3458, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch437 >> Training Loss: tensor(0.3458, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0384, dtype=torch.float64) <<
# tensor(0.3457, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch438 >> Training Loss: tensor(0.3457, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0383, dtype=torch.float64) <<
# tensor(0.3449, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch439 >> Training Loss: tensor(0.3449, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0382, dtype=torch.float64) <<
# tensor(0.3449, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch440 >> Training Loss: tensor(0.3449, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0381, dtype=torch.float64) <<
# tensor(0.3441, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch441 >> Training Loss: tensor(0.3441, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0382, dtype=torch.float64) <<
# tensor(0.3441, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch442 >> Training Loss: tensor(0.3441, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0381, dtype=torch.float64) <<
# tensor(0.3433, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch443 >> Training Loss: tensor(0.3433, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0380, dtype=torch.float64) <<
# tensor(0.3433, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch444 >> Training Loss: tensor(0.3433, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0379, dtype=torch.float64) <<
# tensor(0.3426, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch445 >> Training Loss: tensor(0.3426, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0379, dtype=torch.float64) <<
# tensor(0.3425, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch446 >> Training Loss: tensor(0.3425, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0378, dtype=torch.float64) <<
# tensor(0.3418, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch447 >> Training Loss: tensor(0.3418, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0378, dtype=torch.float64) <<
# tensor(0.3418, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch448 >> Training Loss: tensor(0.3418, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0377, dtype=torch.float64) <<
# tensor(0.3411, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch449 >> Training Loss: tensor(0.3411, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0377, dtype=torch.float64) <<
# tensor(0.3410, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch450 >> Training Loss: tensor(0.3410, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0376, dtype=torch.float64) <<
# tensor(0.3404, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch451 >> Training Loss: tensor(0.3404, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0376, dtype=torch.float64) <<
# tensor(0.3402, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch452 >> Training Loss: tensor(0.3402, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0375, dtype=torch.float64) <<
# tensor(0.3397, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch453 >> Training Loss: tensor(0.3397, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0375, dtype=torch.float64) <<
# tensor(0.3395, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch454 >> Training Loss: tensor(0.3395, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0374, dtype=torch.float64) <<
# tensor(0.3390, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch455 >> Training Loss: tensor(0.3390, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0374, dtype=torch.float64) <<
# tensor(0.3387, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch456 >> Training Loss: tensor(0.3387, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0374, dtype=torch.float64) <<
# tensor(0.3383, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch457 >> Training Loss: tensor(0.3383, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0373, dtype=torch.float64) <<
# tensor(0.3380, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch458 >> Training Loss: tensor(0.3380, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0373, dtype=torch.float64) <<
# tensor(0.3376, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch459 >> Training Loss: tensor(0.3376, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0372, dtype=torch.float64) <<
# tensor(0.3372, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch460 >> Training Loss: tensor(0.3372, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0372, dtype=torch.float64) <<
# tensor(0.3369, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch461 >> Training Loss: tensor(0.3369, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0372, dtype=torch.float64) <<
# tensor(0.3365, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch462 >> Training Loss: tensor(0.3365, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0371, dtype=torch.float64) <<
# tensor(0.3361, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch463 >> Training Loss: tensor(0.3361, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0371, dtype=torch.float64) <<
# tensor(0.3357, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch464 >> Training Loss: tensor(0.3357, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0370, dtype=torch.float64) <<
# tensor(0.3354, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch465 >> Training Loss: tensor(0.3354, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0370, dtype=torch.float64) <<
# tensor(0.3349, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch466 >> Training Loss: tensor(0.3349, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0369, dtype=torch.float64) <<
# tensor(0.3346, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch467 >> Training Loss: tensor(0.3346, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0369, dtype=torch.float64) <<
# tensor(0.3341, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch468 >> Training Loss: tensor(0.3341, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0369, dtype=torch.float64) <<
# tensor(0.3338, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch469 >> Training Loss: tensor(0.3338, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0368, dtype=torch.float64) <<
# tensor(0.3333, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch470 >> Training Loss: tensor(0.3333, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0368, dtype=torch.float64) <<
# tensor(0.3329, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch471 >> Training Loss: tensor(0.3329, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0367, dtype=torch.float64) <<
# tensor(0.3325, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch472 >> Training Loss: tensor(0.3325, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0367, dtype=torch.float64) <<
# tensor(0.3321, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch473 >> Training Loss: tensor(0.3321, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0366, dtype=torch.float64) <<
# tensor(0.3316, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch474 >> Training Loss: tensor(0.3316, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0366, dtype=torch.float64) <<
# tensor(0.3312, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch475 >> Training Loss: tensor(0.3312, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0366, dtype=torch.float64) <<
# tensor(0.3307, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch476 >> Training Loss: tensor(0.3307, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0365, dtype=torch.float64) <<
# tensor(0.3302, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch477 >> Training Loss: tensor(0.3302, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0365, dtype=torch.float64) <<
# tensor(0.3297, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch478 >> Training Loss: tensor(0.3297, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0364, dtype=torch.float64) <<
# tensor(0.3292, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch479 >> Training Loss: tensor(0.3292, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0364, dtype=torch.float64) <<
# tensor(0.3287, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch480 >> Training Loss: tensor(0.3287, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0363, dtype=torch.float64) <<
# tensor(0.3282, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch481 >> Training Loss: tensor(0.3282, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0363, dtype=torch.float64) <<
# tensor(0.3277, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch482 >> Training Loss: tensor(0.3277, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0362, dtype=torch.float64) <<
# tensor(0.3271, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch483 >> Training Loss: tensor(0.3271, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0362, dtype=torch.float64) <<
# tensor(0.3266, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch484 >> Training Loss: tensor(0.3266, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0361, dtype=torch.float64) <<
# tensor(0.3260, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch485 >> Training Loss: tensor(0.3260, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0361, dtype=torch.float64) <<
# tensor(0.3254, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch486 >> Training Loss: tensor(0.3254, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0360, dtype=torch.float64) <<
# tensor(0.3248, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch487 >> Training Loss: tensor(0.3248, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0359, dtype=torch.float64) <<
# tensor(0.3242, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch488 >> Training Loss: tensor(0.3242, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0359, dtype=torch.float64) <<
# tensor(0.3236, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch489 >> Training Loss: tensor(0.3236, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0358, dtype=torch.float64) <<
# tensor(0.3229, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch490 >> Training Loss: tensor(0.3229, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0358, dtype=torch.float64) <<
# tensor(0.3222, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch491 >> Training Loss: tensor(0.3222, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0357, dtype=torch.float64) <<
# tensor(0.3215, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch492 >> Training Loss: tensor(0.3215, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0356, dtype=torch.float64) <<
# tensor(0.3208, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch493 >> Training Loss: tensor(0.3208, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0356, dtype=torch.float64) <<
# tensor(0.3201, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch494 >> Training Loss: tensor(0.3201, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0355, dtype=torch.float64) <<
# tensor(0.3194, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch495 >> Training Loss: tensor(0.3194, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0354, dtype=torch.float64) <<
# tensor(0.3186, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch496 >> Training Loss: tensor(0.3186, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0354, dtype=torch.float64) <<
# tensor(0.3178, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch497 >> Training Loss: tensor(0.3178, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0353, dtype=torch.float64) <<
# tensor(0.3171, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch498 >> Training Loss: tensor(0.3171, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0352, dtype=torch.float64) <<
# tensor(0.3162, dtype=torch.float64, grad_fn=<AddBackward0>)
# Epoch499 >> Training Loss: tensor(0.3162, dtype=torch.float64, grad_fn=<AddBackward0>) Validation Loss: tensor(0.0351, dtype=torch.float64) <<

# %%
TRT_LOSS = []
for t in TR_LOSS:
    cc = t.detach().numpy()
    TRT_LOSS.append(cc)

# %%
plt.plot(TRT_LOSS)
plt.plot(VAL_LOSS)
plt.show()

# %%
accumulated_test_loss = 0.0
net.reset_hidden_states(bs=1)
it_test = iter(data_loaded.test_dataloader)
c=0
while c < int(X_test.shape[0]/1):
    #net.eval()
    with torch.set_grad_enabled(False):
        #print(c)
        c = c+1
        item = next(it_test)
        outputs = net(item[0])
        accumulated_test_loss = accumulated_test_loss + criterion(outputs, item[1])        
print(accumulated_test_loss/int(len(data_loaded.test_dataloader)))
# Out:
# tensor(0.0074, dtype=torch.float64)

# %%
import pandas as pd

# %%
#os.mkdir('RESULTS_LOSS')

# %%
tr_loss_array = []
for z in TR_LOSS:
    tr_loss_array.append(z.tolist())
training_loss = pd.DataFrame(tr_loss_array, columns=['TR_LOSS'])
training_loss.to_csv('../RESULTS_LOSS/TR_LOSS_'+str(output_cardinality)+'.csv')

# %%
val_loss_array = []
for z in VAL_LOSS:
    val_loss_array.append(z.tolist())
val_loss = pd.DataFrame(val_loss_array, columns=['VAL_LOSS'])
val_loss.to_csv('../RESULTS_LOSS/VAL_LOSS_'+str(output_cardinality)+'.csv')

# %%
test_loss_array = [accumulated_test_loss]

test2_loss = pd.DataFrame(test_loss_array, columns=['TEST_LOSS'])
test2_loss.to_csv('../RESULTS_LOSS/TEST_LOSS_'+str(output_cardinality)+'.csv')

# %%
# SAVE THE SCALER
import joblib
scaler_filename = "../SCALER_DUMPS/min_max_scaler_lookahead"+str(output_cardinality)+".save"
joblib.dump(scaler, scaler_filename) 
# And now to load...
# Out:
# ['../SCALER_DUMPS/min_max_scaler_lookahead9.save']

# %%
#SAVE MODEL
model_ckp_path = "../MODEL_CHECKPOINTS/model_lookahead"+str(output_cardinality)+".pth" 
torch.save(net.state_dict(), model_ckp_path)

# %%
#net2 = LSTMNET(batch_size=batch_size,input_len=input_cardinality,output_len=output_cardinality)
#net2.load_state_dict(torch.load(model_ckp_path))
#net2.eval()
#scaler = joblib.load(scaler_filename)
