# %%
input_cardinality=20
output_cardinality=4

# %%
import torch
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import sklearn.model_selection as sk
import torch.autograd as autograd
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

# %%
#import pytorch_lightning as pl
import time
import copy
from tqdm import tqdm
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow
# Out:
# 2023-06-14 13:06:38.459082: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-14 13:06:38.629099: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-06-14 13:06:39.189222: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/toor/Desktop/catkin_ism/devel/lib:/opt/ros/noetic/lib
# 2023-06-14 13:06:39.189340: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/toor/Desktop/catkin_ism/devel/lib:/opt/ros/noetic/lib
# 2023-06-14 13:06:39.189347: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
torch.manual_seed(0)
def seed_worker(worker_id):
    worker_seed = torch.initial_seed() % 2**32
    np.random.seed(worker_seed)
    random.seed(worker_seed)

g = torch.Generator()
g.manual_seed(0)
tensorflow.random.set_seed(1234)

# %%
#from pytorch_lightning.callbacks import ModelCheckpoint, EarlyStopping
#from pytorch_lightning.loggers import TensorBoardLogger

# %%
device = torch.device("cpu" if torch.cuda.is_available() else "cpu")

# %%
#pl.seed_everything(43)

# %%
class DATA:
    def __init__(self, data_path):
        self.data_path = data_path
        self.filenames = os.listdir(DATA_PATH)
        self.filenames = [filename for filename in self.filenames if filename.endswith(".csv")]
        self.len_filenames = len(self.filenames)

    def get_data(self):
        self.data = []
        for i in range(len(self.filenames)):
            self.data.append(self.read_data(i))
        return self.data

    def read_data(self,i):
        return pd.read_csv(self.data_path+"/"+self.filenames[i])


    def process_data(self, scaler, input_cardinality=20, output_cardinality=10, cols=['ThetaXHG']):
        self.datasamples = self.get_data()
        X = []
        y = []
        X_scaled = []
        y_scaled = []
        for i, datasample in enumerate(self.datasamples):
            #for j in range(datasample[cols].shape[0]-output_cardinality):
            #    print('Input' +str(j)+ ' to '+str(j+input_cardinality) + 'Output: '+str(j+input_cardinality)+ ' to '+str(j+input_cardinality+output_cardinality))
            #Append to X (TO MAKE A LIST OF LISTS), [[0.019,1.02,...., upto input_cardinality]]
            #Append to Y (TO MAKE A LIST OF LISTS), [[0.019,1.02,...., upto output_cardinality]]
            #start of Y will be ahead of end of X by 1

            for j in range(datasample.shape[0]-output_cardinality-input_cardinality+1):
                X.append(datasample[cols].iloc[j:j+input_cardinality].to_numpy())
                y.append(datasample[cols].iloc[j+input_cardinality: j+input_cardinality+output_cardinality].to_numpy())
                X_scaled.append(scaler.transform(datasample[cols].iloc[j:j+input_cardinality].to_numpy()))
                y_scaled.append(scaler.transform(datasample[cols].iloc[j+input_cardinality: j+input_cardinality+output_cardinality].to_numpy()))

        #return self.datasamples, X, y
        #print(np.array(X).shape,np.array(y).shape,np.array(X_scaled).shape, np.array(y_scaled).shape)
        return self.datasamples, np.array(X), np.array(y), np.array(X_scaled), np.array(y_scaled)


    def train_test_split(self, X, y, split={'train':0.8,'val':0.2, 'test':0.5}):
        #print(X)
        self.X_train, self.X_val_test, self.y_train, self.y_val_test = sk.train_test_split(X, y, test_size=split['val'] , random_state=43)
        self.X_test, self.X_val, self.y_test, self.y_val = sk.train_test_split(self.X_val_test, self.y_val_test, test_size=split['test'] , random_state=43)

        return (self.X_train, self.y_train), (self.X_val, self.X_test), (self.X_test, self.y_test)

    def keras_train_test_split(self, X, y, split={'train':0.9,'test':0.1}):
        #print(X)
        self.X_train_val, self.X_test, self.y_train_val, self.y_test = sk.train_test_split(X, y, test_size=split['test'] , random_state=43)

        return (self.X_train_val, self.y_train_val), (self.X_test, self.y_test)



    def getscaler(self,cols):
        self.datasamples = self.get_data()
        for i, sample in enumerate(self.datasamples):
            if i ==0:
                features = pd.DataFrame(sample[cols])
            else:
                features = pd.DataFrame.append(features, sample[cols]) #sample[cols]

        #scaling
        scaler = MinMaxScaler(feature_range=(-1,1))
        scaler = scaler.fit(features)
        features_scaled = pd.DataFrame(scaler.transform(features), index = features.index, columns = cols)
        return scaler

        """
        #convert back to datasamples
        #save to X
        #save to X_scaled


        #Split treain test and validation

        for i in range(features.shape[0]):
            self.datasamples = []




        return features, features_scaled
        """

# %%
class THETADATASET(Dataset):
    #convert to pytorch dataset
    def __init__(self, X, y):
        self.X = X
        self.y = y
    def __len__(self):
        return len(self.X)
    def __getitem__(self, idx):
        sequence, output = self.X[idx], self.y[idx]
        return (torch.from_numpy(sequence.reshape(-1)), torch.from_numpy(output.reshape(-1)))
        #return dict(sequence=torch.tensor(sequence.reshape(-1),dtype=torch.float64), label=torch.tensor(output.reshape(-1),dtype=torch.float64))

# %%
class THETADATASETLOADER():
    def __init__(self, data, batchsize, bs_val):
        super().__init__()
        self.data = data
        self.batchsize = batchsize
        self.train_dataset = THETADATASET(self.data.X_train, self.data.y_train)
        self.val_dataset = THETADATASET(self.data.X_val, self.data.y_val)
        self.test_dataset = THETADATASET(self.data.X_test, self.data.y_test)
        self.train_dataloader = DataLoader(self.train_dataset, batch_size = self.batchsize, shuffle= False, num_workers=0)
        self.val_dataloader = DataLoader(self.val_dataset, batch_size = bs_val, shuffle= False, num_workers=0)
        self.test_dataloader = DataLoader(self.test_dataset, batch_size = 1, shuffle= False, num_workers=0)

# %%
epochs=200
batch_size = 16
bs_val = 16
DATA_PATH = "../DATASET/TRANSORMER_DATA"
data = DATA(DATA_PATH)
cols=['ThetaXHG']
scaler = data.getscaler(cols)
input_shape = (input_cardinality,1)

# %%
samples, X, y, X_scaled, y_scaled = data.process_data(scaler, input_cardinality=input_cardinality, output_cardinality=output_cardinality, cols=['ThetaXHG'])
(X_train_val, y_train_val), (X_test, y_test) = data.keras_train_test_split(X_scaled,y_scaled,  split={'train':0.9,'test':0.1})

# %%
X_train_val.shape, y_train_val.shape,  X_test.shape, y_test.shape
# Out:
# ((1044, 20, 1), (1044, 4, 1), (117, 20, 1), (117, 4, 1))

# %%
class TRANSFORMER:
    def __init__(self):
        pass

    def definition(self,input_shape, output_cardinality, head_size,num_heads,ff_dim,num_transformer_blocks,mlp_units,dropout=0,mlp_dropout=0):
        inputs = keras.Input(shape=input_shape)
        x = inputs
        for _ in range(num_transformer_blocks):
            x = self.transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

        x = layers.GlobalAveragePooling1D(data_format="channels_first")(x)
        for dim in mlp_units:
            x = layers.Dense(dim, activation="relu")(x)
            x = layers.Dropout(mlp_dropout)(x)
        outputs = layers.Dense(output_cardinality)(x)
        return keras.Model(inputs, outputs)

    def transformer_encoder(self,inputs, head_size, num_heads, ff_dim, dropout=0):
        # Normalization and Attention
        x = layers.LayerNormalization(epsilon=1e-6)(inputs)
        x = layers.MultiHeadAttention(key_dim=head_size, num_heads=num_heads, dropout=dropout)(x, x)
        x = layers.Dropout(dropout)(x)
        res = x + inputs

        # Feed Forward Part
        x = layers.LayerNormalization(epsilon=1e-6)(res)
        x = layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(x)
        x = layers.Dropout(dropout)(x)
        x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)
        return x + res

# %%
"""
class TRANSFORMER_ENCODER_MODEL:
    def __init__(self):
        pass

    def definition(self,input_shape,head_size,num_heads,ff_dim,num_transformer_blocks,mlp_units,dropout=0,mlp_dropout=0):
        inputs = keras.Input(shape=input_shape)
        x = inputs
        for _ in range(num_transformer_blocks):
            x = self.transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

        x = layers.GlobalAveragePooling1D(data_format="channels_first")(x)
        for dim in mlp_units:
            x = layers.Dense(dim, activation="relu")(x)
            x = layers.Dropout(mlp_dropout)(x)
        outputs = layers.Dense(1)(x)
        return keras.Model(inputs, outputs)

    def transformer_encoder(self,inputs, head_size, num_heads, ff_dim, dropout=0):
        # Normalization and Attention
        x = layers.LayerNormalization(epsilon=1e-6)(inputs)
        x = layers.MultiHeadAttention(key_dim=head_size, num_heads=num_heads, dropout=dropout)(x, x)
        x = layers.Dropout(dropout)(x)
        res = x + inputs

        # Feed Forward Part
        x = layers.LayerNormalization(epsilon=1e-6)(res)
        x = layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(x)
        x = layers.Dropout(dropout)(x)
        x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)
        return x + res
"""
# Out:
# '\nclass TRANSFORMER_ENCODER_MODEL:\n    def __init__(self):\n        pass\n\n    def definition(self,input_shape,head_size,num_heads,ff_dim,num_transformer_blocks,mlp_units,dropout=0,mlp_dropout=0):\n        inputs = keras.Input(shape=input_shape)\n        x = inputs\n        for _ in range(num_transformer_blocks):\n            x = self.transformer_encoder(x, head_size, num_heads, ff_dim, dropout)\n\n        x = layers.GlobalAveragePooling1D(data_format="channels_first")(x)\n        for dim in mlp_units:\n            x = layers.Dense(dim, activation="relu")(x)\n            x = layers.Dropout(mlp_dropout)(x)\n        outputs = layers.Dense(1)(x)\n        return keras.Model(inputs, outputs)\n\n    def transformer_encoder(self,inputs, head_size, num_heads, ff_dim, dropout=0):\n        # Normalization and Attention\n        x = layers.LayerNormalization(epsilon=1e-6)(inputs)\n        x = layers.MultiHeadAttention(key_dim=head_size, num_heads=num_heads, dropout=dropout)(x, x)\n        x = layers.Dropout(dropout)(x)\n        res = x + inputs\n\n        # Feed Forward Part\n        x = layers.LayerNormalization(epsilon=1e-6)(res)\n        x = layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(x)\n        x = layers.Dropout(dropout)(x)\n        x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)\n        return x + res\n'

# %%
"""
net = LSTMNET(batch_size=batch_size,input_len=input_cardinality,output_len=output_cardinality)
net = net.to(device)
net = net.double()
criterion = nn.MSELoss()
optimizer = optim.Adam(net.parameters(),lr=1e-1)
"""
# Out:
# '\nnet = LSTMNET(batch_size=batch_size,input_len=input_cardinality,output_len=output_cardinality)\nnet = net.to(device)\nnet = net.double()\ncriterion = nn.MSELoss()\noptimizer = optim.Adam(net.parameters(),lr=1e-1)\n'

# %%
transformer_model = TRANSFORMER()
transformer_predictor = transformer_model.definition(input_shape, output_cardinality,head_size=256, num_heads=4, ff_dim=4, num_transformer_blocks=4, mlp_units=[128], mlp_dropout=0.4,dropout=0.25)
# Out:
# 2023-06-14 13:06:43.062073: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-14 13:06:43.064812: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/toor/Desktop/catkin_ism/devel/lib:/opt/ros/noetic/lib
# 2023-06-14 13:06:43.065498: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/toor/Desktop/catkin_ism/devel/lib:/opt/ros/noetic/lib
# 2023-06-14 13:06:43.065511: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1934] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2023-06-14 13:06:43.065713: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
transformer_predictor.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 20, 1)]      0           []
#
#  layer_normalization (LayerNorm  (None, 20, 1)       2           ['input_1[0][0]']
#  alization)
#
#  multi_head_attention (MultiHea  (None, 20, 1)       7169        ['layer_normalization[0][0]',
#  dAttention)                                                      'layer_normalization[0][0]']
#
#  dropout (Dropout)              (None, 20, 1)        0           ['multi_head_attention[0][0]']
#
#  tf.__operators__.add (TFOpLamb  (None, 20, 1)       0           ['dropout[0][0]',
#  da)                                                              'input_1[0][0]']
#
#  layer_normalization_1 (LayerNo  (None, 20, 1)       2           ['tf.__operators__.add[0][0]']
#  rmalization)
#
#  conv1d (Conv1D)                (None, 20, 4)        8           ['layer_normalization_1[0][0]']
#
#  dropout_1 (Dropout)            (None, 20, 4)        0           ['conv1d[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 20, 1)        5           ['dropout_1[0][0]']
#
#  tf.__operators__.add_1 (TFOpLa  (None, 20, 1)       0           ['conv1d_1[0][0]',
#  mbda)                                                            'tf.__operators__.add[0][0]']
#
#  layer_normalization_2 (LayerNo  (None, 20, 1)       2           ['tf.__operators__.add_1[0][0]']
#  rmalization)
#
#  multi_head_attention_1 (MultiH  (None, 20, 1)       7169        ['layer_normalization_2[0][0]',
#  eadAttention)                                                    'layer_normalization_2[0][0]']
#
#  dropout_2 (Dropout)            (None, 20, 1)        0           ['multi_head_attention_1[0][0]']
#
#  tf.__operators__.add_2 (TFOpLa  (None, 20, 1)       0           ['dropout_2[0][0]',
#  mbda)                                                            'tf.__operators__.add_1[0][0]']
#
#  layer_normalization_3 (LayerNo  (None, 20, 1)       2           ['tf.__operators__.add_2[0][0]']
#  rmalization)
#
#  conv1d_2 (Conv1D)              (None, 20, 4)        8           ['layer_normalization_3[0][0]']
#
#  dropout_3 (Dropout)            (None, 20, 4)        0           ['conv1d_2[0][0]']
#
#  conv1d_3 (Conv1D)              (None, 20, 1)        5           ['dropout_3[0][0]']
#
#  tf.__operators__.add_3 (TFOpLa  (None, 20, 1)       0           ['conv1d_3[0][0]',
#  mbda)                                                            'tf.__operators__.add_2[0][0]']
#
#  layer_normalization_4 (LayerNo  (None, 20, 1)       2           ['tf.__operators__.add_3[0][0]']
#  rmalization)
#
#  multi_head_attention_2 (MultiH  (None, 20, 1)       7169        ['layer_normalization_4[0][0]',
#  eadAttention)                                                    'layer_normalization_4[0][0]']
#
#  dropout_4 (Dropout)            (None, 20, 1)        0           ['multi_head_attention_2[0][0]']
#
#  tf.__operators__.add_4 (TFOpLa  (None, 20, 1)       0           ['dropout_4[0][0]',
#  mbda)                                                            'tf.__operators__.add_3[0][0]']
#
#  layer_normalization_5 (LayerNo  (None, 20, 1)       2           ['tf.__operators__.add_4[0][0]']
#  rmalization)
#
#  conv1d_4 (Conv1D)              (None, 20, 4)        8           ['layer_normalization_5[0][0]']
#
#  dropout_5 (Dropout)            (None, 20, 4)        0           ['conv1d_4[0][0]']
#
#  conv1d_5 (Conv1D)              (None, 20, 1)        5           ['dropout_5[0][0]']
#
#  tf.__operators__.add_5 (TFOpLa  (None, 20, 1)       0           ['conv1d_5[0][0]',
#  mbda)                                                            'tf.__operators__.add_4[0][0]']
#
#  layer_normalization_6 (LayerNo  (None, 20, 1)       2           ['tf.__operators__.add_5[0][0]']
#  rmalization)
#
#  multi_head_attention_3 (MultiH  (None, 20, 1)       7169        ['layer_normalization_6[0][0]',
#  eadAttention)                                                    'layer_normalization_6[0][0]']
#
#  dropout_6 (Dropout)            (None, 20, 1)        0           ['multi_head_attention_3[0][0]']
#
#  tf.__operators__.add_6 (TFOpLa  (None, 20, 1)       0           ['dropout_6[0][0]',
#  mbda)                                                            'tf.__operators__.add_5[0][0]']
#
#  layer_normalization_7 (LayerNo  (None, 20, 1)       2           ['tf.__operators__.add_6[0][0]']
#  rmalization)
#
#  conv1d_6 (Conv1D)              (None, 20, 4)        8           ['layer_normalization_7[0][0]']
#
#  dropout_7 (Dropout)            (None, 20, 4)        0           ['conv1d_6[0][0]']
#
#  conv1d_7 (Conv1D)              (None, 20, 1)        5           ['dropout_7[0][0]']
#
#  tf.__operators__.add_7 (TFOpLa  (None, 20, 1)       0           ['conv1d_7[0][0]',
#  mbda)                                                            'tf.__operators__.add_6[0][0]']
#
#  global_average_pooling1d (Glob  (None, 20)          0           ['tf.__operators__.add_7[0][0]']
#  alAveragePooling1D)
#
#  dense (Dense)                  (None, 128)          2688        ['global_average_pooling1d[0][0]'
#                                                                  ]
#
#  dropout_8 (Dropout)            (None, 128)          0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 4)            516         ['dropout_8[0][0]']
#
# ==================================================================================================
# Total params: 31,948
# Trainable params: 31,948
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
transformer_predictor.compile(loss="mean_squared_error", optimizer=keras.optimizers.Adam(learning_rate=1e-4))
#model.summary()

# %%
stats = transformer_predictor.fit(X_train_val,y_train_val,epochs=epochs,batch_size=batch_size, validation_split = 0.1)
# Out:
# Epoch 1/200
# 59/59 [==============================] - 5s 39ms/step - loss: 0.2642 - val_loss: 0.1211
# Epoch 2/200
# 59/59 [==============================] - 2s 32ms/step - loss: 0.1438 - val_loss: 0.0777
# Epoch 3/200
# 59/59 [==============================] - 2s 34ms/step - loss: 0.1060 - val_loss: 0.0656
# Epoch 4/200
# 59/59 [==============================] - 2s 34ms/step - loss: 0.0914 - val_loss: 0.0547
# Epoch 5/200
# 59/59 [==============================] - 2s 35ms/step - loss: 0.0795 - val_loss: 0.0434
# Epoch 6/200
# 59/59 [==============================] - 2s 33ms/step - loss: 0.0676 - val_loss: 0.0368
# Epoch 7/200
# 59/59 [==============================] - 2s 33ms/step - loss: 0.0598 - val_loss: 0.0339
# Epoch 8/200
# 59/59 [==============================] - 2s 33ms/step - loss: 0.0517 - val_loss: 0.0242
# Epoch 9/200
# 59/59 [==============================] - 2s 32ms/step - loss: 0.0463 - val_loss: 0.0209
# Epoch 10/200
# 59/59 [==============================] - 2s 42ms/step - loss: 0.0411 - val_loss: 0.0168
# Epoch 11/200
# 59/59 [==============================] - 2s 40ms/step - loss: 0.0383 - val_loss: 0.0138
# Epoch 12/200
# 59/59 [==============================] - 2s 42ms/step - loss: 0.0356 - val_loss: 0.0113
# Epoch 13/200
# 59/59 [==============================] - 3s 43ms/step - loss: 0.0324 - val_loss: 0.0106
# Epoch 14/200
# 59/59 [==============================] - 3s 42ms/step - loss: 0.0291 - val_loss: 0.0094
# Epoch 15/200
# 59/59 [==============================] - 2s 42ms/step - loss: 0.0289 - val_loss: 0.0105
# Epoch 16/200
# 59/59 [==============================] - 3s 44ms/step - loss: 0.0269 - val_loss: 0.0090
# Epoch 17/200
# 59/59 [==============================] - 3s 46ms/step - loss: 0.0249 - val_loss: 0.0074
# Epoch 18/200
# 59/59 [==============================] - 3s 45ms/step - loss: 0.0232 - val_loss: 0.0083
# Epoch 19/200
# 59/59 [==============================] - 3s 44ms/step - loss: 0.0226 - val_loss: 0.0069
# Epoch 20/200
# 59/59 [==============================] - 3s 44ms/step - loss: 0.0231 - val_loss: 0.0066
# Epoch 21/200
# 59/59 [==============================] - 3s 44ms/step - loss: 0.0223 - val_loss: 0.0064
# Epoch 22/200
# 59/59 [==============================] - 3s 52ms/step - loss: 0.0212 - val_loss: 0.0064
# Epoch 23/200
# 59/59 [==============================] - 3s 52ms/step - loss: 0.0209 - val_loss: 0.0060
# Epoch 24/200
# 59/59 [==============================] - 3s 53ms/step - loss: 0.0205 - val_loss: 0.0062
# Epoch 25/200
# 59/59 [==============================] - 3s 54ms/step - loss: 0.0192 - val_loss: 0.0057
# Epoch 26/200
# 59/59 [==============================] - 3s 56ms/step - loss: 0.0183 - val_loss: 0.0060
# Epoch 27/200
# 59/59 [==============================] - 3s 58ms/step - loss: 0.0180 - val_loss: 0.0056
# Epoch 28/200
# 59/59 [==============================] - 4s 60ms/step - loss: 0.0179 - val_loss: 0.0053
# Epoch 29/200
# 59/59 [==============================] - 3s 56ms/step - loss: 0.0172 - val_loss: 0.0053
# Epoch 30/200
# 59/59 [==============================] - 3s 56ms/step - loss: 0.0153 - val_loss: 0.0052
# Epoch 31/200
# 59/59 [==============================] - 4s 60ms/step - loss: 0.0166 - val_loss: 0.0051
# Epoch 32/200
# 59/59 [==============================] - 4s 64ms/step - loss: 0.0156 - val_loss: 0.0049
# Epoch 33/200
# 59/59 [==============================] - 4s 69ms/step - loss: 0.0155 - val_loss: 0.0048
# Epoch 34/200
# 59/59 [==============================] - 4s 72ms/step - loss: 0.0158 - val_loss: 0.0046
# Epoch 35/200
# 59/59 [==============================] - 4s 71ms/step - loss: 0.0152 - val_loss: 0.0047
# Epoch 36/200
# 59/59 [==============================] - 4s 72ms/step - loss: 0.0143 - val_loss: 0.0044
# Epoch 37/200
# 59/59 [==============================] - 5s 82ms/step - loss: 0.0136 - val_loss: 0.0044
# Epoch 38/200
# 59/59 [==============================] - 5s 88ms/step - loss: 0.0147 - val_loss: 0.0049
# Epoch 39/200
# 59/59 [==============================] - 5s 88ms/step - loss: 0.0134 - val_loss: 0.0043
# Epoch 40/200
# 59/59 [==============================] - 5s 86ms/step - loss: 0.0138 - val_loss: 0.0045
# Epoch 41/200
# 59/59 [==============================] - 5s 87ms/step - loss: 0.0132 - val_loss: 0.0043
# Epoch 42/200
# 59/59 [==============================] - 6s 99ms/step - loss: 0.0123 - val_loss: 0.0039
# Epoch 43/200
# 59/59 [==============================] - 6s 100ms/step - loss: 0.0123 - val_loss: 0.0039
# Epoch 44/200
# 59/59 [==============================] - 6s 103ms/step - loss: 0.0129 - val_loss: 0.0048
# Epoch 45/200
# 59/59 [==============================] - 6s 106ms/step - loss: 0.0127 - val_loss: 0.0039
# Epoch 46/200
# 59/59 [==============================] - 7s 111ms/step - loss: 0.0127 - val_loss: 0.0038
# Epoch 47/200
# 59/59 [==============================] - 7s 114ms/step - loss: 0.0119 - val_loss: 0.0037
# Epoch 48/200
# 59/59 [==============================] - 7s 118ms/step - loss: 0.0116 - val_loss: 0.0039
# Epoch 49/200
# 59/59 [==============================] - 7s 112ms/step - loss: 0.0111 - val_loss: 0.0038
# Epoch 50/200
# 59/59 [==============================] - 7s 118ms/step - loss: 0.0120 - val_loss: 0.0035
# Epoch 51/200
# 59/59 [==============================] - 7s 122ms/step - loss: 0.0111 - val_loss: 0.0035
# Epoch 52/200
# 59/59 [==============================] - 7s 118ms/step - loss: 0.0117 - val_loss: 0.0037
# Epoch 53/200
# 59/59 [==============================] - 7s 118ms/step - loss: 0.0111 - val_loss: 0.0038
# Epoch 54/200
# 59/59 [==============================] - 8s 131ms/step - loss: 0.0117 - val_loss: 0.0034
# Epoch 55/200
# 59/59 [==============================] - 8s 134ms/step - loss: 0.0112 - val_loss: 0.0035
# Epoch 56/200
# 59/59 [==============================] - 8s 133ms/step - loss: 0.0104 - val_loss: 0.0038
# Epoch 57/200
# 59/59 [==============================] - 9s 148ms/step - loss: 0.0115 - val_loss: 0.0034
# Epoch 58/200
# 59/59 [==============================] - 9s 148ms/step - loss: 0.0106 - val_loss: 0.0037
# Epoch 59/200
# 59/59 [==============================] - 9s 150ms/step - loss: 0.0107 - val_loss: 0.0039
# Epoch 60/200
# 59/59 [==============================] - 9s 148ms/step - loss: 0.0102 - val_loss: 0.0034
# Epoch 61/200
# 59/59 [==============================] - 9s 147ms/step - loss: 0.0112 - val_loss: 0.0033
# Epoch 62/200
# 59/59 [==============================] - 9s 148ms/step - loss: 0.0097 - val_loss: 0.0033
# Epoch 63/200
# 59/59 [==============================] - 8s 144ms/step - loss: 0.0094 - val_loss: 0.0035
# Epoch 64/200
# 59/59 [==============================] - 9s 145ms/step - loss: 0.0102 - val_loss: 0.0033
# Epoch 65/200
# 59/59 [==============================] - 9s 146ms/step - loss: 0.0096 - val_loss: 0.0032
# Epoch 66/200
# 59/59 [==============================] - 9s 147ms/step - loss: 0.0097 - val_loss: 0.0032
# Epoch 67/200
# 59/59 [==============================] - 9s 148ms/step - loss: 0.0092 - val_loss: 0.0033
# Epoch 68/200
# 59/59 [==============================] - 8s 144ms/step - loss: 0.0097 - val_loss: 0.0032
# Epoch 69/200
# 59/59 [==============================] - 8s 144ms/step - loss: 0.0093 - val_loss: 0.0032
# Epoch 70/200
# 59/59 [==============================] - 9s 150ms/step - loss: 0.0100 - val_loss: 0.0032
# Epoch 71/200
# 59/59 [==============================] - 9s 150ms/step - loss: 0.0092 - val_loss: 0.0032
# Epoch 72/200
# 59/59 [==============================] - 9s 160ms/step - loss: 0.0087 - val_loss: 0.0035
# Epoch 73/200
# 59/59 [==============================] - 9s 157ms/step - loss: 0.0089 - val_loss: 0.0032
# Epoch 74/200
# 59/59 [==============================] - 9s 156ms/step - loss: 0.0083 - val_loss: 0.0032
# Epoch 75/200
# 59/59 [==============================] - 9s 150ms/step - loss: 0.0091 - val_loss: 0.0030
# Epoch 76/200
# 59/59 [==============================] - 9s 147ms/step - loss: 0.0091 - val_loss: 0.0031
# Epoch 77/200
# 59/59 [==============================] - 8s 134ms/step - loss: 0.0089 - val_loss: 0.0031
# Epoch 78/200
# 59/59 [==============================] - 8s 144ms/step - loss: 0.0086 - val_loss: 0.0030
# Epoch 79/200
# 59/59 [==============================] - 8s 135ms/step - loss: 0.0085 - val_loss: 0.0031
# Epoch 80/200
# 59/59 [==============================] - 8s 144ms/step - loss: 0.0083 - val_loss: 0.0030
# Epoch 81/200
# 59/59 [==============================] - 8s 138ms/step - loss: 0.0086 - val_loss: 0.0030
# Epoch 82/200
# 59/59 [==============================] - 8s 133ms/step - loss: 0.0088 - val_loss: 0.0029
# Epoch 83/200
# 59/59 [==============================] - 8s 139ms/step - loss: 0.0085 - val_loss: 0.0031
# Epoch 84/200
# 59/59 [==============================] - 8s 137ms/step - loss: 0.0079 - val_loss: 0.0030
# Epoch 85/200
# 59/59 [==============================] - 8s 134ms/step - loss: 0.0083 - val_loss: 0.0030
# Epoch 86/200
# 59/59 [==============================] - 8s 132ms/step - loss: 0.0078 - val_loss: 0.0032
# Epoch 87/200
# 59/59 [==============================] - 8s 136ms/step - loss: 0.0080 - val_loss: 0.0030
# Epoch 88/200
# 59/59 [==============================] - 8s 138ms/step - loss: 0.0079 - val_loss: 0.0032
# Epoch 89/200
# 59/59 [==============================] - 8s 138ms/step - loss: 0.0074 - val_loss: 0.0029
# Epoch 90/200
# 59/59 [==============================] - 8s 137ms/step - loss: 0.0078 - val_loss: 0.0030
# Epoch 91/200
# 59/59 [==============================] - 8s 136ms/step - loss: 0.0075 - val_loss: 0.0032
# Epoch 92/200
# 59/59 [==============================] - 8s 137ms/step - loss: 0.0073 - val_loss: 0.0028
# Epoch 93/200
# 59/59 [==============================] - 8s 133ms/step - loss: 0.0079 - val_loss: 0.0030
# Epoch 94/200
# 59/59 [==============================] - 8s 134ms/step - loss: 0.0071 - val_loss: 0.0028
# Epoch 95/200
# 59/59 [==============================] - 8s 134ms/step - loss: 0.0073 - val_loss: 0.0028
# Epoch 96/200
# 59/59 [==============================] - 8s 136ms/step - loss: 0.0075 - val_loss: 0.0032
# Epoch 97/200
# 59/59 [==============================] - 8s 138ms/step - loss: 0.0070 - val_loss: 0.0030
# Epoch 98/200
# 59/59 [==============================] - 8s 132ms/step - loss: 0.0072 - val_loss: 0.0030
# Epoch 99/200
# 59/59 [==============================] - 8s 137ms/step - loss: 0.0076 - val_loss: 0.0030
# Epoch 100/200
# 59/59 [==============================] - 8s 137ms/step - loss: 0.0072 - val_loss: 0.0030
# Epoch 101/200
# 59/59 [==============================] - 8s 135ms/step - loss: 0.0073 - val_loss: 0.0028
# Epoch 102/200
# 59/59 [==============================] - 8s 134ms/step - loss: 0.0071 - val_loss: 0.0031
# Epoch 103/200
# 59/59 [==============================] - 8s 134ms/step - loss: 0.0070 - val_loss: 0.0030
# Epoch 104/200
# 59/59 [==============================] - 8s 142ms/step - loss: 0.0072 - val_loss: 0.0028
# Epoch 105/200
# 59/59 [==============================] - 8s 136ms/step - loss: 0.0067 - val_loss: 0.0027
# Epoch 106/200
# 59/59 [==============================] - 8s 139ms/step - loss: 0.0066 - val_loss: 0.0029
# Epoch 107/200
# 59/59 [==============================] - 8s 135ms/step - loss: 0.0066 - val_loss: 0.0028
# Epoch 108/200
# 59/59 [==============================] - 8s 135ms/step - loss: 0.0067 - val_loss: 0.0027
# Epoch 109/200
# 59/59 [==============================] - 8s 131ms/step - loss: 0.0067 - val_loss: 0.0028
# Epoch 110/200
# 59/59 [==============================] - 8s 139ms/step - loss: 0.0068 - val_loss: 0.0028
# Epoch 111/200
# 59/59 [==============================] - 8s 137ms/step - loss: 0.0068 - val_loss: 0.0030
# Epoch 112/200
# 59/59 [==============================] - 8s 138ms/step - loss: 0.0072 - val_loss: 0.0027
# Epoch 113/200
# 59/59 [==============================] - 8s 138ms/step - loss: 0.0069 - val_loss: 0.0027
# Epoch 114/200
# 59/59 [==============================] - 8s 132ms/step - loss: 0.0062 - val_loss: 0.0027
# Epoch 115/200
# 59/59 [==============================] - 8s 137ms/step - loss: 0.0068 - val_loss: 0.0028
# Epoch 116/200
# 59/59 [==============================] - 8s 135ms/step - loss: 0.0063 - val_loss: 0.0027
# Epoch 117/200
# 59/59 [==============================] - 8s 138ms/step - loss: 0.0065 - val_loss: 0.0031
# Epoch 118/200
# 59/59 [==============================] - 8s 136ms/step - loss: 0.0067 - val_loss: 0.0028
# Epoch 119/200
# 59/59 [==============================] - 8s 134ms/step - loss: 0.0059 - val_loss: 0.0027
# Epoch 120/200
# 59/59 [==============================] - 8s 134ms/step - loss: 0.0066 - val_loss: 0.0026
# Epoch 121/200
# 59/59 [==============================] - 8s 136ms/step - loss: 0.0062 - val_loss: 0.0026
# Epoch 122/200
# 59/59 [==============================] - 8s 138ms/step - loss: 0.0060 - val_loss: 0.0026
# Epoch 123/200
# 59/59 [==============================] - 8s 133ms/step - loss: 0.0059 - val_loss: 0.0026
# Epoch 124/200
# 59/59 [==============================] - 8s 135ms/step - loss: 0.0065 - val_loss: 0.0027
# Epoch 125/200
# 59/59 [==============================] - 8s 138ms/step - loss: 0.0064 - val_loss: 0.0027
# Epoch 126/200
# 59/59 [==============================] - 8s 137ms/step - loss: 0.0063 - val_loss: 0.0025
# Epoch 127/200
# 59/59 [==============================] - 8s 139ms/step - loss: 0.0058 - val_loss: 0.0026
# Epoch 128/200
# 59/59 [==============================] - 8s 138ms/step - loss: 0.0058 - val_loss: 0.0026
# Epoch 129/200
# 59/59 [==============================] - 8s 135ms/step - loss: 0.0062 - val_loss: 0.0027
# Epoch 130/200
# 59/59 [==============================] - 8s 139ms/step - loss: 0.0057 - val_loss: 0.0026
# Epoch 131/200
# 59/59 [==============================] - 8s 142ms/step - loss: 0.0061 - val_loss: 0.0026
# Epoch 132/200
# 59/59 [==============================] - 8s 137ms/step - loss: 0.0060 - val_loss: 0.0023
# Epoch 133/200
# 59/59 [==============================] - 8s 140ms/step - loss: 0.0061 - val_loss: 0.0023
# Epoch 134/200
# 59/59 [==============================] - 8s 129ms/step - loss: 0.0058 - val_loss: 0.0023
# Epoch 135/200
# 59/59 [==============================] - 8s 132ms/step - loss: 0.0057 - val_loss: 0.0024
# Epoch 136/200
# 59/59 [==============================] - 8s 138ms/step - loss: 0.0061 - val_loss: 0.0028
# Epoch 137/200
# 59/59 [==============================] - 8s 135ms/step - loss: 0.0059 - val_loss: 0.0027
# Epoch 138/200
# 59/59 [==============================] - 8s 131ms/step - loss: 0.0058 - val_loss: 0.0026
# Epoch 139/200
# 59/59 [==============================] - 8s 130ms/step - loss: 0.0054 - val_loss: 0.0025
# Epoch 140/200
# 59/59 [==============================] - 7s 125ms/step - loss: 0.0059 - val_loss: 0.0025
# Epoch 141/200
# 59/59 [==============================] - 7s 125ms/step - loss: 0.0053 - val_loss: 0.0026
# Epoch 142/200
# 59/59 [==============================] - 7s 116ms/step - loss: 0.0056 - val_loss: 0.0026
# Epoch 143/200
# 59/59 [==============================] - 7s 118ms/step - loss: 0.0054 - val_loss: 0.0026
# Epoch 144/200
# 59/59 [==============================] - 7s 118ms/step - loss: 0.0053 - val_loss: 0.0026
# Epoch 145/200
# 59/59 [==============================] - 7s 119ms/step - loss: 0.0052 - val_loss: 0.0026
# Epoch 146/200
# 59/59 [==============================] - 7s 118ms/step - loss: 0.0056 - val_loss: 0.0027
# Epoch 147/200
# 59/59 [==============================] - 7s 118ms/step - loss: 0.0059 - val_loss: 0.0028
# Epoch 148/200
# 59/59 [==============================] - 7s 121ms/step - loss: 0.0052 - val_loss: 0.0027
# Epoch 149/200
# 59/59 [==============================] - 7s 113ms/step - loss: 0.0059 - val_loss: 0.0028
# Epoch 150/200
# 59/59 [==============================] - 7s 119ms/step - loss: 0.0052 - val_loss: 0.0028
# Epoch 151/200
# 59/59 [==============================] - 7s 118ms/step - loss: 0.0057 - val_loss: 0.0026
# Epoch 152/200
# 59/59 [==============================] - 7s 117ms/step - loss: 0.0049 - val_loss: 0.0027
# Epoch 153/200
# 59/59 [==============================] - 7s 119ms/step - loss: 0.0057 - val_loss: 0.0026
# Epoch 154/200
# 59/59 [==============================] - 7s 122ms/step - loss: 0.0052 - val_loss: 0.0026
# Epoch 155/200
# 59/59 [==============================] - 7s 116ms/step - loss: 0.0055 - val_loss: 0.0024
# Epoch 156/200
# 59/59 [==============================] - 7s 122ms/step - loss: 0.0054 - val_loss: 0.0026
# Epoch 157/200
# 59/59 [==============================] - 7s 117ms/step - loss: 0.0056 - val_loss: 0.0029
# Epoch 158/200
# 59/59 [==============================] - 7s 118ms/step - loss: 0.0048 - val_loss: 0.0025
# Epoch 159/200
# 59/59 [==============================] - 7s 116ms/step - loss: 0.0052 - val_loss: 0.0024
# Epoch 160/200
# 59/59 [==============================] - 7s 120ms/step - loss: 0.0052 - val_loss: 0.0024
# Epoch 161/200
# 59/59 [==============================] - 7s 118ms/step - loss: 0.0051 - val_loss: 0.0025
# Epoch 162/200
# 59/59 [==============================] - 7s 119ms/step - loss: 0.0053 - val_loss: 0.0025
# Epoch 163/200
# 59/59 [==============================] - 7s 118ms/step - loss: 0.0051 - val_loss: 0.0026
# Epoch 164/200
# 59/59 [==============================] - 7s 116ms/step - loss: 0.0053 - val_loss: 0.0024
# Epoch 165/200
# 59/59 [==============================] - 7s 116ms/step - loss: 0.0053 - val_loss: 0.0024
# Epoch 166/200
# 59/59 [==============================] - 7s 116ms/step - loss: 0.0048 - val_loss: 0.0026
# Epoch 167/200
# 59/59 [==============================] - 7s 115ms/step - loss: 0.0054 - val_loss: 0.0027
# Epoch 168/200
# 59/59 [==============================] - 7s 119ms/step - loss: 0.0052 - val_loss: 0.0025
# Epoch 169/200
# 59/59 [==============================] - 7s 119ms/step - loss: 0.0054 - val_loss: 0.0025
# Epoch 170/200
# 59/59 [==============================] - 7s 119ms/step - loss: 0.0047 - val_loss: 0.0024
# Epoch 171/200
# 59/59 [==============================] - 7s 121ms/step - loss: 0.0049 - val_loss: 0.0023
# Epoch 172/200
# 59/59 [==============================] - 7s 111ms/step - loss: 0.0051 - val_loss: 0.0025
# Epoch 173/200
# 59/59 [==============================] - 6s 100ms/step - loss: 0.0050 - val_loss: 0.0024
# Epoch 174/200
# 59/59 [==============================] - 6s 108ms/step - loss: 0.0048 - val_loss: 0.0024
# Epoch 175/200
# 59/59 [==============================] - 6s 101ms/step - loss: 0.0051 - val_loss: 0.0024
# Epoch 176/200
# 59/59 [==============================] - 6s 103ms/step - loss: 0.0053 - val_loss: 0.0027
# Epoch 177/200
# 59/59 [==============================] - 6s 103ms/step - loss: 0.0052 - val_loss: 0.0025
# Epoch 178/200
# 59/59 [==============================] - 6s 101ms/step - loss: 0.0046 - val_loss: 0.0025
# Epoch 179/200
# 59/59 [==============================] - 6s 103ms/step - loss: 0.0050 - val_loss: 0.0024
# Epoch 180/200
# 59/59 [==============================] - 6s 102ms/step - loss: 0.0053 - val_loss: 0.0025
# Epoch 181/200
# 59/59 [==============================] - 6s 105ms/step - loss: 0.0047 - val_loss: 0.0023
# Epoch 182/200
# 59/59 [==============================] - 6s 105ms/step - loss: 0.0054 - val_loss: 0.0023
# Epoch 183/200
# 59/59 [==============================] - 6s 105ms/step - loss: 0.0047 - val_loss: 0.0026
# Epoch 184/200
# 59/59 [==============================] - 6s 101ms/step - loss: 0.0050 - val_loss: 0.0026
# Epoch 185/200
# 59/59 [==============================] - 6s 107ms/step - loss: 0.0045 - val_loss: 0.0027
# Epoch 186/200
# 59/59 [==============================] - 6s 106ms/step - loss: 0.0048 - val_loss: 0.0025
# Epoch 187/200
# 59/59 [==============================] - 6s 102ms/step - loss: 0.0050 - val_loss: 0.0027
# Epoch 188/200
# 59/59 [==============================] - 6s 102ms/step - loss: 0.0044 - val_loss: 0.0024
# Epoch 189/200
# 59/59 [==============================] - 6s 101ms/step - loss: 0.0048 - val_loss: 0.0024
# Epoch 190/200
# 59/59 [==============================] - 6s 102ms/step - loss: 0.0049 - val_loss: 0.0025
# Epoch 191/200
# 59/59 [==============================] - 6s 102ms/step - loss: 0.0047 - val_loss: 0.0023
# Epoch 192/200
# 59/59 [==============================] - 6s 109ms/step - loss: 0.0048 - val_loss: 0.0024
# Epoch 193/200
# 59/59 [==============================] - 6s 100ms/step - loss: 0.0046 - val_loss: 0.0026
# Epoch 194/200
# 59/59 [==============================] - 6s 101ms/step - loss: 0.0046 - val_loss: 0.0025
# Epoch 195/200
# 59/59 [==============================] - 6s 102ms/step - loss: 0.0046 - val_loss: 0.0025
# Epoch 196/200
# 59/59 [==============================] - 6s 101ms/step - loss: 0.0047 - val_loss: 0.0026
# Epoch 197/200
# 59/59 [==============================] - 6s 104ms/step - loss: 0.0050 - val_loss: 0.0025
# Epoch 198/200
# 59/59 [==============================] - 6s 103ms/step - loss: 0.0044 - val_loss: 0.0025
# Epoch 199/200
# 59/59 [==============================] - 6s 106ms/step - loss: 0.0044 - val_loss: 0.0025
# Epoch 200/200
# 59/59 [==============================] - 6s 102ms/step - loss: 0.0048 - val_loss: 0.0023

# %%
#os.mkdir('RESULTS_LOSS')

# %%
import os
if not os.path.exists(DATA_PATH+"/../../TRANSFORMER_SCALER_DUMPS/"):
    os.mkdir(DATA_PATH+"/../../TRANSFORMER_SCALER_DUMPS/")

if not os.path.exists(DATA_PATH+"/../../TRANSFORMER_RESULTS_LOSS/"):
    os.mkdir(DATA_PATH+"/../../TRANSFORMER_RESULTS_LOSS/")

if not os.path.exists(DATA_PATH+"/../../TRANSFORMER_CHECKPOINTS/"):
    os.mkdir(DATA_PATH+"/../../TRANSFORMER_CHECKPOINTS/")

# %%
TEST_LOSS = transformer_predictor.evaluate(X_test, y_test)
print(TEST_LOSS)
# Out:
# 4/4 [==============================] - 0s 17ms/step - loss: 7.1803e-04
# 0.0007180341053754091

# %%
# SAVE THE SCALER
import joblib
import os

scaler_filename = DATA_PATH+"/../../TRANSFORMER_SCALER_DUMPS/transformer_min_max_scaler_lookahead"+str(output_cardinality)+".save"
joblib.dump(scaler, scaler_filename)
# And now to load...
# Out:
# ['../DATASET/TRANSORMER_DATA/../../TRANSFORMER_SCALER_DUMPS/transformer_min_max_scaler_lookahead4.save']

# %%
TRT_LOSS = stats.history['loss']
training_loss = pd.DataFrame(TRT_LOSS, columns=['TR_LOSS'])
training_loss.to_csv(DATA_PATH+"/../../TRANSFORMER_RESULTS_LOSS/TRANSFORMER_TR_LOSS_"+str(output_cardinality)+'.csv')

# %%
VAL_LOSS = stats.history['val_loss']
validation_loss = pd.DataFrame(VAL_LOSS, columns=['VAL_LOSS'])
validation_loss.to_csv(DATA_PATH+"/../../TRANSFORMER_RESULTS_LOSS/TRANSFORMER_VAL_LOSS_"+str(output_cardinality)+'.csv')

# %%
test_loss = pd.DataFrame([TEST_LOSS], columns=['TEST_LOSS'])
test_loss.to_csv(DATA_PATH+"/../../TRANSFORMER_RESULTS_LOSS/TRANSFORMER_TEST_LOSS_"+str(output_cardinality)+'.csv')

# %%
transformer_predictor.save(DATA_PATH+"/../../TRANSFORMER_CHECKPOINTS/transformer_lookahead"+str(output_cardinality)+".model")
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 56). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ../DATASET/TRANSORMER_DATA/../../TRANSFORMER_CHECKPOINTS/transformer_lookahead4.model/assets
# INFO:tensorflow:Assets written to: ../DATASET/TRANSORMER_DATA/../../TRANSFORMER_CHECKPOINTS/transformer_lookahead4.model/assets

# %%
#modelnew= tensorflow.keras.models.load_model(DATA_PATH+"/../../TRANSFORMER_CHECKPOINTS/transformer_lookahead"+str(output_cardinality)+".model")

# %%
#modelnew.predict(X_test)
